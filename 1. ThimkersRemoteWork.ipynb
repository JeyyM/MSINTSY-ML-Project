# %% [markdown]
# # **So You want a Remote job? Predicting Remote and Flexible Work Arrangements from Developer Survey Data**
# **Group: Thimkers**
# - Juan Miguel Miranda
# - Lance Xavier Lim
# ---

# %% [markdown]
# ## **Introduction**
# Remote and highly flexible work arrangements have become increasingly coveted among software developers, offering benefits such as improved work-life balance, location flexibility, and expanded employment opportunities even including other countries. However, as remote roles grow more competitive, many job seekers lack clear, data-driven insights into the characteristics commonly associated with such positions.
#
# This project applies supervised machine learning classification techniques to the Stack Overflow 2025 Developer Survey to predict whether a developer works in a remote or highly flexible work arrangement based on demographic, professional, and job-related features. By modeling patterns present in real-world survey data, the study aims to identify factors that are strongly predictive of remote or flexible work status.
#
# ---

# %% [markdown]
# ## **Dataset Description**
#
# **Description**
#
# This project uses data from the Stack Overflow 2025 Developer Survey, a large-scale, annual survey conducted among software developers worldwide. The survey collects self-reported information on demographics, education, employment status, work arrangements, technologies used, and professional experience.
#
# **survey_results_public.csv**
#
# This file contains all of the survey responses, where each row represents a single respondent. Columns correspond to survey questions covering topics such as employment characteristics, work environment, developer role, experience level, education background, and technology usage. Responses include a mix of numerical values, categorical selections, and multi-select answers. This file serves as the main source of data.
#
# **survey_results_schema.csv**
#
# This file provides the metadata and schema for the multiple select questions within the survey.
#
# **Why This Is a Real-World Dataset and Relevant to the Problem**
#
# The Stack Overflow Developer Survey is a real-world dataset collected annually from a large and diverse population of developers. The data reflects self-reported information about respondents' actual employment conditions, work environments, and professional backgrounds, rather than synthetic or simulated data. As a result, the dataset captures real labor market conditions and work arrangements experienced by developers.
#
# The dataset is directly relevant to the problem of predicting remote and flexible work arrangements because it explicitly includes questions about respondents' current work situations, including whether they work remotely, in person, or under flexible arrangements. Additionally, the survey contains a wide range of demographic, professional, and organizational variables. Such as role type, years of experience, education level, company characteristics, and more that can plausibly relate to work arrangement outcomes.
#
# Because remote work has become increasingly competitive and sought after in the software industry, understanding which characteristics are predictive of remote or highly flexible roles is a socially and professionally relevant task applicable to job seekers and recruiters.
#
# ### **Problem Definition and Machine Learning Task**
#
# Can we build a supervised machine learning model that predicts whether a developer is employed in a remote or highly flexible work arrangement based on their professional background, using the Stack Overflow 2025 Developer Survey?
#
# ---

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ### **Scope and Inclusion**
#
# In this project, the analysis focuses exclusively on respondents' current professional situation as captured by the Stack Overflow 2025 Developer Survey. To ensure that the predictive task reflects present-day employment conditions rather than future intentions or subjective opinions, only variables describing respondents' existing work arrangement, professional background, industry, experience, and current technology usage are considered.
#
# Specifically, the study excludes variables that relate to future interests such as technologies respondents wish to work with in the coming year, as these do not describe their current employment situation. Preference-based and opinion-oriented responses such as personal rankings, preferences, and thoughts regarding AI will be omitted due to their subjective nature and limited relevance to predicting present work situations. Additionally, write-in "Other" custom text fields are excluded in favor of standardized response options provided by the surveyors to maintain consistency and reduce noise.
#
# The feature set is further restricted to general industry and professional characteristics which means that questions related to Stack Overflow community engagement are excluded, as these reflect community interaction rather than employment conditions.
#
# This scoped feature selection allows the model to focus on stable, interpretable characteristics that might plausibly relate to a developer's current work arrangement, while avoiding future-oriented thoughts, subjective preferences, and community-specific behaviors that fall outside the objective of the model.
#
# ---
#
# ### **Survey Coverage**
#
# To efficiently explore, clean, and prepare the features for modeling, the dataset is processed section by section, following the order and structure of the Stack Overflow 2025 Developer Survey. This approach allows each group of related variables to be examined, cleaned, and transformed independently before being integrated before being used for training. For each section, missing values are identified and handled, categorical variables are standardized and encoded as needed.
#
# The following sections of the survey are included in the analysis:
#
# - **Education + Career**
#
# This section contains variables describing respondents' demographic background and current professional status. Included features capture education level, years of experience, job role, and **current work arrangement**. These variables provide a foundational profile of a developer's career stage and work context.
#
# - **Tech and Tech Culture**
#
# This section includes respondents' current technology usage in professional settings. Variables indicate whether respondents actively worked with programming languages, database systems, web frameworks, and other tools in the past year. Only features reflecting technologies already used are included. Questions describing technologies respondents wish to use in the future or custom write-ins are excluded.
#
# - **AI + AI Agents**
#
# From the AI-related section, only variables describing current AI tool and AI agent usage are included. These features capture whether respondents presently use AI tools and agents as part of their work. Subjective variables such as opinions about AI, trust levels, or frustrations are excluded since they reflect subjective beliefs.
#
# ---

# %%
# %pip install scikit_posthocs
# %pip install scikit-learn
# %pip install plotly

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

from scipy import stats
from scipy.stats import mannwhitneyu
from scipy.stats import gaussian_kde

from scipy.stats import pearsonr, spearmanr, levene, f_oneway, shapiro, kruskal, chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

survey_data = pd.read_csv('survey_results_public.csv')
survey_schema = pd.read_csv('survey_results_schema.csv') # I don't think this is needed

print(f"Survey data shape: {survey_data.shape}")
print(f"Schema data shape: {survey_schema.shape}")

survey_data.head()
# Out:
# C:\Users\lance\AppData\Local\Temp\ipykernel_21720\2881597891.py:29: DtypeWarning:
#
# Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
# Survey data shape: (49191, 172)
# Schema data shape: (139, 6)
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %% [markdown]
# ### **Functions Import**

# %%
import importlib
import functions
importlib.reload(functions)

funcs = functions.Functions()

# %% [markdown]
# ### **Checking Duplicates**
#
# None were found

# %%
results = funcs.view_duplicates(survey_data)
# Out:
# Duplicate Row Check:
# Total rows: 49191
# Duplicate rows: 0

# %% [markdown]
# ### **Creating Target Variable**
#
# The target variable can be found in the RemoteWork column. To define successes and failures, full Remote and Your Choice as both successes. Marking them both as 1 and all else as 0. In future analysis, NA or nan will be considered as not currently employed.

# %%
remote_flexible_conditions = [
    'Remote',
    'Your choice (very flexible, you can come in when you want or just as needed)'
]

target = survey_data['RemoteWork'].apply(
    lambda x: 1 if x in remote_flexible_conditions else 0
)

print("Target Variables:")
target_counts = target.value_counts()
total_rows = len(target)

for value, count in target_counts.items():
    percentage = (count / total_rows) * 100
    print(f"{value}: {count} ({percentage:.2f}%)")
# Out:
# Target Variables:
# 0: 34016 (69.15%)
# 1: 15175 (30.85%)

# %% [markdown]
# ### **Education + Career**

# %% [markdown]
# **Current Profession**
#
# The original current profession variable (main branch) contains six nominal categories:
#
# - I am a developer by profession
# - I am not primarily a developer, but I write code sometimes as part of my work/studies
# - I am learning to code
# - I code primarily as a hobby
# - I used to be a developer by profession, but no longer am
# - I work with developers or my work supports developers but am not a developer by profession
#
# To reduce noise and over-fragmentation, these responses were compressed into four groupings that better reflect respondents’ current level of professional involvement. To make it digestible to ML models, the categories were one-hot encoded.
#
# | Compressed Category     | Original Responses                                                                                                                          |
# | ----------------------- | ------------------------------------------------------------------------------------------------------------------------------------------- |
# | Professional dev    | I am a developer by profession                                                                                                              |
# | Non-primary dev     | I am not primarily a developer, but I write code sometimes as part of my work/studies                                                       |
# | Learner or hobbyist | I am learning to code; I code primarily as a hobby                                                                                          |
# | Retired or non-dev  | I used to be a developer by profession, but no longer am; I work with developers or support developers but am not a developer by profession |

# %%
current_profession = survey_data['MainBranch'].apply(funcs.compress_mainbranch)
# Put a prefix on all one-hot encoded columns to make sure none ever get mixed up
current_profession_encoded = pd.get_dummies(current_profession, prefix='profession')

print(f"\nOne-hot encoded features created:")
print(f"Shape: {current_profession_encoded.shape}")
print(f"Columns: {list(current_profession_encoded.columns)}")

current_profession_encoded
# Out:
# One-hot encoded features created:
# Shape: (49191, 4)
# Columns: ['profession_learner or hobbyist', 'profession_non-primary dev', 'profession_professional dev', 'profession_retired or non-dev']
#        profession_learner or hobbyist  profession_non-primary dev  \
# 0                               False                       False
# 1                               False                       False
# 2                               False                       False
# 3                               False                       False
# 4                               False                       False
# ...                               ...                         ...
# 49186                            True                       False
# 49187                           False                       False
# 49188                           False                       False
# 49189                           False                       False
# ...

# %% [markdown]
# ### **Age Group, Highest Education Level, and Employment**
#
# To prepare the categorical variables for machine learning modeling, compression and one-hot encoding was applied to reduce noise and make columns more concise.
#
# **Compression Strategy Overview:**
#
# 1. **Current Profession (MainBranch)**: Compressed from 6 original categories to 4 groupings:
# - Professional developer
# - Non-primary developer (code sometimes)
# - Learner or hobbyist
# - Retired or non-developer
#
# 2. **Education Level**: Compressed from 9 original categories to 8 standardized levels, with NaN values put into to "other":
# - bachelor, master, professional, associate
# - went to college without degree, secondary school, primary school
# - other
#
# 3. **Employment Status**: Compressed from 7 original categories to 6 employment status:
# - employed, independent, unemployed,  students
# - retired, others (includes NaN and "prefer not to say")

# %%
# One-hot encode Age groups
age_group = pd.get_dummies(survey_data['Age'], prefix='age_group')

print(f"\nOne-hot encoded age groups:")
print(f"Shape: {age_group.shape}")
print(f"Columns: {list(age_group.columns)}")

# One-hot encode education levels
compressed_education = survey_data['EdLevel'].apply(funcs.compress_education)
education_level = pd.get_dummies(compressed_education, prefix='ed_level')

print(f"\nOne-hot encoded education levels:")
print(f"Shape: {education_level.shape}")
print(f"Columns: {list(education_level.columns)}")

# One-hot encode Employment status
compressed_employment = survey_data['Employment'].apply(funcs.compress_employment)
employment_status = pd.get_dummies(compressed_employment, prefix='employment')

print(f"\nOne-hot encoded employment status:")
print(f"Shape: {employment_status.shape}")
print(f"Columns: {list(employment_status.columns)}")

employment_status
# Out:
# One-hot encoded age groups:
# Shape: (49191, 7)
# Columns: ['age_group_18-24 years old', 'age_group_25-34 years old', 'age_group_35-44 years old', 'age_group_45-54 years old', 'age_group_55-64 years old', 'age_group_65 years or older', 'age_group_Prefer not to say']
#
# One-hot encoded education levels:
# Shape: (49191, 8)
# Columns: ['ed_level_associate', 'ed_level_bachelor', 'ed_level_master', 'ed_level_other', 'ed_level_primary school', 'ed_level_professional', 'ed_level_secondary school', 'ed_level_went to college without degree']
#
# One-hot encoded employment status:
# Shape: (49191, 6)
# Columns: ['employment_employed', 'employment_independent', 'employment_others', 'employment_retired', 'employment_student', 'employment_unemployed']
#        employment_employed  employment_independent  employment_others  \
# 0                     True                   False              False
# 1                     True                   False              False
# ...

# %% [markdown]
# ### **Developer Type**
#
# The DevType variable originally contained 33 distinct developer roles and specializations. To create more meaningful feature groups, these were compressed into 22 categories to combine smaller groups and create wider yet accurate generalizations.
#
# **Developer Categories:**
# - Full-stack, Backend, Frontend, Mobile, Desktop, Embedded, Game, AI/ML developers
#
# **Specialized Roles:**
# - Software architects, Data specialists, DevOps/Infrastructure, Database specialists, Security specialists, UX/UI designers
#
# **Other Professional Roles:**
# - QA, Managers, Executives/Founders, Researchers/Scientists, Support/Analysts
#
# **Non-Professional:**
# - Students, Retired, Others (including NaN and unspecified)

# %%
# One-hot encode Developer Type
compressed_devtype = survey_data['DevType'].apply(funcs.compress_devtype)
dev_type_encoded = pd.get_dummies(compressed_devtype, prefix='devtype')

print(f"\nOne-hot encoded developer types:")
print(f"Shape: {dev_type_encoded.shape}")
print(f"Columns: {list(dev_type_encoded.columns)}")

# Show the compression results
print(f"\nCompressed developer type distribution:")
devtype_counts = compressed_devtype.value_counts()
total_rows = len(compressed_devtype)

dev_type_encoded
# Out:
# One-hot encoded developer types:
# Shape: (49191, 22)
# Columns: ['devtype_ai/ml developer', 'devtype_backend developer', 'devtype_data specialist', 'devtype_database specialist', 'devtype_desktop developer', 'devtype_devops/infrastructure', 'devtype_embedded developer', 'devtype_executive/leader', 'devtype_frontend developer', 'devtype_full-stack developer', 'devtype_game developer', 'devtype_manager', 'devtype_mobile developer', 'devtype_others', 'devtype_qa tester', 'devtype_researcher/scientist', 'devtype_retired', 'devtype_security specialist', 'devtype_software architect', 'devtype_student', 'devtype_support/analyst', 'devtype_ux/ui designer']
#
# Compressed developer type distribution:
#        devtype_ai/ml developer  devtype_backend developer  \
# 0                        False                      False
# 1                        False                       True
# 2                        False                      False
# ...

# %% [markdown]
# ### **Years and Experience**
#
# Just a general overview of numerical data.
#
# SCALE AFTER TRAIN TEST SPLIT

# %%
work_years = survey_data["WorkExp"]
learn_years = survey_data["YearsCode"]

work_summary = work_years.describe()
print(work_summary)

print("")

learn_summary = learn_years.describe()
print(learn_summary)

work_years.hist(bins=50)
plt.title("WorkExp distribution")
plt.xlabel("Years of professional experience")
plt.ylabel("Frequency")
plt.show()

learn_years.hist(bins=50)
plt.title("YearsCode distribution")
plt.xlabel("Years of coding experience")
plt.ylabel("Frequency")
plt.show()
# Out:
# count    42893.000000
# mean        13.367403
# std         10.800117
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         20.000000
# max        100.000000
# Name: WorkExp, dtype: float64
#
# count    43042.000000
# mean        16.570861
# std         11.787610
# min          1.000000
# 25%          8.000000
# 50%         14.000000
# 75%         24.000000
# max        100.000000
# Name: YearsCode, dtype: float64

# %% [markdown]
# ### **Organization Size**
#
# The organization size variable contains categories that represent a natural ordering from smallest to largest companies. Unlike the previous categorical variables that are purely nominal.
#
# Because of this, it was assigned and ordered from 0 to 8 to preserve the natural ordering.

# %%
org_size_ordinal = survey_data['OrgSize'].apply(funcs.orgsize_ordinal)

print(f"\nOrdinal value distribution:")
ordinal_counts = org_size_ordinal.value_counts().sort_index()
total_rows = len(org_size_ordinal)

for value, count in ordinal_counts.items():
    percentage = (count / total_rows) * 100
    print(f"Value {value}: {count} ({percentage:.2f}%)")
# Out:
# Ordinal value distribution:
# Value 0: 15945 (32.41%)
# Value 1: 1763 (3.58%)
# Value 2: 5600 (11.38%)
# Value 3: 6688 (13.60%)
# Value 4: 6109 (12.42%)
# Value 5: 2361 (4.80%)
# Value 6: 4156 (8.45%)
# Value 7: 1604 (3.26%)
# Value 8: 4965 (10.09%)

# %% [markdown]
# ### **How Many Distinct Software Do You Use**
#
# The survey includes questions about the number of distinct software tools developers use both for work and personal projects. These variables capture the range in their toolkits..
#
# The original responses contained a very wide range of values, from 0 to extremely high numbers like 999. Many of these extreme values appear to be unserious responses so tool counts were put into 6 groups:
#    - 0 tools
#    - 1 to 5 tools
#    - 6 to 10 tools
#    - 11 to 15 tools
#    - 16 to 20 tools
#    - More than 20 tools

# %%
work_tool_count = survey_data['ToolCountWork'].apply(funcs.process_tool_count)
work_tool_groups = work_tool_count.apply(funcs.group_tool_count)

print("Tool Counts (Work):")
tool_counts = work_tool_count.value_counts().sort_index()
total_rows = len(work_tool_count)

# print(f"\Counts Distribution:")
# for value, count in tool_counts.items():
#     percentage = (count / total_rows) * 100
#     print(f"{value} tools: {count} ({percentage:.2f}%)")

print(f"\nSummary statistics:")
print(f"Mean: {work_tool_count.mean():.2f}")
print(f"Median: {work_tool_count.median():.0f}")
print(f"Standard deviation: {work_tool_count.std():.2f}")

work_tool_groups_counts = work_tool_groups.value_counts()
total_rows = len(work_tool_groups)

print(f"\nTool Count Groups Distribution:")
for group in ['0', '1 to 5', '6 to 10', '11 to 15', '16 to 20', 'More than 20']:
    count = work_tool_groups_counts.get(group, 0)
    percentage = (count / total_rows) * 100
    print(f"{group} tools: {count} ({percentage:.2f}%)")
# Out:
# Tool Counts (Work):
#
# Summary statistics:
# Mean: 9.95
# Median: 3
# Standard deviation: 202.33
#
# Tool Count Groups Distribution:
# 0 tools: 21744 (44.20%)
# 1 to 5 tools: 12486 (25.38%)
# 6 to 10 tools: 9716 (19.75%)
# 11 to 15 tools: 2612 (5.31%)
# 16 to 20 tools: 1407 (2.86%)
# More than 20 tools: 1226 (2.49%)

# %%
personal_tool_count = survey_data['ToolCountPersonal'].apply(funcs.process_tool_count)
personal_tool_groups = personal_tool_count.apply(funcs.group_tool_count)

print("Tool Counts (Work):")
tool_counts = personal_tool_count.value_counts().sort_index()
total_rows = len(personal_tool_count)

# print(f"\Counts Distribution:")
# for value, count in tool_counts.items():
#     percentage = (count / total_rows) * 100
#     print(f"{value} tools: {count} ({percentage:.2f}%)")

print(f"\nSummary statistics:")
print(f"Mean: {personal_tool_count.mean():.2f}")
print(f"Median: {personal_tool_count.median():.0f}")
print(f"Standard deviation: {personal_tool_count.std():.2f}")

personal_tool_groups_counts = personal_tool_groups.value_counts()
total_rows = len(personal_tool_groups)

print(f"\nTool Count Groups Distribution:")
for group in ['0', '1 to 5', '6 to 10', '11 to 15', '16 to 20', 'More than 20']:
    count = personal_tool_groups_counts.get(group, 0)
    percentage = (count / total_rows) * 100
    print(f"{group} tools: {count} ({percentage:.2f}%)")
# Out:
# Tool Counts (Work):
#
# Summary statistics:
# Mean: 4.44
# Median: 1
# Standard deviation: 32.49
#
# Tool Count Groups Distribution:
# 0 tools: 24299 (49.40%)
# 1 to 5 tools: 16476 (33.49%)
# 6 to 10 tools: 5693 (11.57%)
# 11 to 15 tools: 1165 (2.37%)
# 16 to 20 tools: 752 (1.53%)
# More than 20 tools: 806 (1.64%)

# %% [markdown]
# ### **Country**
#
# The Country variable originally contains over 170+ different countries. To make this more manageable for machine learning and to capture meaningful geographic patterns that might relate to remote work culture, countries were grouped using the UN Geoscheme as the standard.
#
# - **Northern America**: USA, Canada
# - **Western Europe**: Germany, UK, France, Netherlands, Switzerland, etc.
# - **Northern Europe**: Sweden, Norway, Denmark, Finland, Iceland, Baltic states
# - **Southern Europe**: Spain, Italy, Portugal, Greece, Malta, Cyprus, Croatia, Slovenia
# - **Eastern Europe**: Poland, Czech Republic, Ukraine, Hungary, Romania, Russia, etc.
# - **Eastern Asia**: China, Japan, South Korea, North Korea, Mongolia, Taiwan, Hong Kong
# - **South-Eastern Asia**: Philippines, Indonesia, Thailand, Malaysia, Vietnam, Singapore, etc.
# - **Southern Asia**: India, Pakistan, Bangladesh, Sri Lanka, Nepal, Afghanistan, etc.
# - **Western Asia**: Turkey, Israel, Jordan, Lebanon, Saudi Arabia, UAE, Iran, etc.
# - **Central Asia**: Kazakhstan, Uzbekistan, Turkmenistan, Kyrgyzstan, Tajikistan
# - **Northern Africa**: Egypt, Libya, Tunisia, Algeria, Morocco, Sudan
# - **Western Africa**: Nigeria, Ghana, Senegal, Mali, etc.
# - **Eastern Africa**: Kenya, Uganda, Tanzania, Ethiopia, Rwanda, Madagascar, etc.
# - **Middle Africa**: Cameroon, Chad, Democratic Republic of Congo, Angola, etc.
# - **Southern Africa**: South Africa, Botswana, Namibia, Zimbabwe, Zambia, etc.
# - **Central America**: Mexico, Guatemala, Honduras, El Salvador, Nicaragua, Costa Rica, Panama, Belize
# - **Caribbean**: Cuba, Dominican Republic, Jamaica, Trinidad and Tobago, Haiti, etc.
# - **South America**: Brazil, Argentina, Chile, Colombia, Peru, Venezuela, Ecuador, etc.
# - **Australia and New Zealand**: Australia, New Zealand, Fiji
# - **Other**: Microstates, dependencies, and unspecified countries

# %%
# Apply geographic grouping to countries
geographic_regions = survey_data['Country'].apply(funcs.group_countries)
geographic_regions_encoded = pd.get_dummies(geographic_regions, prefix='region')

print("Geographic Regions Distribution:")
region_counts = geographic_regions.value_counts()
total_rows = len(geographic_regions)

for region, count in region_counts.items():
    percentage = (count / total_rows) * 100
    print(f"{region}: {count} ({percentage:.2f}%)")

geographic_regions_encoded
# Out:
# Geographic Regions Distribution:
# other: 13806 (28.07%)
# western_europe: 8852 (18.00%)
# northern_america: 8538 (17.36%)
# eastern_europe: 3816 (7.76%)
# southern_asia: 3209 (6.52%)
# southern_europe: 2333 (4.74%)
# northern_europe: 1669 (3.39%)
# south_america: 1610 (3.27%)
# western_asia: 1084 (2.20%)
# australia_new_zealand: 1064 (2.16%)
# south_eastern_asia: 792 (1.61%)
# eastern_asia: 732 (1.49%)
# central_america: 388 (0.79%)
# southern_africa: 303 (0.62%)
# northern_africa: 295 (0.60%)
# western_africa: 282 (0.57%)
# eastern_africa: 265 (0.54%)
# caribbean: 61 (0.12%)
# central_asia: 59 (0.12%)
# middle_africa: 33 (0.07%)
#        region_australia_new_zealand  region_caribbean  region_central_america  \
# 0                             False             False                   False
# 1                             False             False                   False
# 2                             False             False                   False
# ...

# %%
# Check which countries are being classified as "other"
other_countries = funcs.print_other_countries(survey_data)
# Out:
# Nomadic: 29 (0.06%)
# Isle of Man: 10 (0.02%)
# Andorra: 6 (0.01%)
# Papua New Guinea: 3 (0.01%)
# Micronesia, Federated States of...: 2 (0.00%)
# San Marino: 1 (0.00%)
# Palau: 1 (0.00%)
# Total 'other': 52 (0.11%)

# %% [markdown]
# ### **Yearly Compensation**
#
# The yearly compensation variable represents total compensation. While this would be a valuable predictor for remote work arrangements, several significant data quality issues make it unsuitable.
#
# 1. **High Missing Data Rate**: Nearly 50% of responses have missing compensation data since disclosure is optional and sensitive.
# 2. **Extreme Outliers**: The dataset contains questionable entries exceeding realistic compensation ranges, which severely skew the mean and standard deviation.
# 3. **Optional Data**: Since compensation disclosure is voluntary, the available data may not be representative of real-world conditions as well as have bias in sampling.
#
# Given these substantial data quality issues, yearly compensation is excluded from the feature set. Additionally, since geographic regions are already captured, currency information would be unnecessary as well.

# %%
yearly_compensation = survey_data["CompTotal"]

yearly_compensation_summary = yearly_compensation.describe()
print(yearly_compensation_summary)

zero_count = (yearly_compensation == 0).sum()
nan_count = yearly_compensation.isna().sum()
total_count = len(yearly_compensation)

print(f"Zero values: {zero_count:,} ({zero_count/total_count*100:.2f}%)")
print(f"NaN values: {nan_count:,} ({nan_count/total_count*100:.2f}%)")
# Out:
# count    2.486600e+04
# mean     2.234198e+70
# std      3.523096e+72
# min      0.000000e+00
# 25%      5.500000e+04
# 50%      1.050000e+05
# 75%      2.400000e+05
# max      5.555556e+74
# Name: CompTotal, dtype: float64
# Zero values: 751 (1.53%)
# NaN values: 24,325 (49.45%)

# %% [markdown]
# ## **Technology Skills and Tools**
#
# The Stack Overflow 2025 Developer Survey captures extensive information about the technologies, tools, and platforms that developers actively used in the past year. These multi-select questions provide valuable insights into skill sets that may correlate with remote work opportunities.
#
# **Feature Engineering System:**
# The multi-select approach results in multiple items separated by a semicolon such as:
# Dart;HTML/CSS;JavaScript;TypeScript. Sometimes with more than 40 different tools to select. Where respondents pick those that they extensively used in the past year.
#
# **Top 25% Selection Strategy:**
#
# Based on the Pareto Principle (80/20 rule) with additional allowance, we select the top 25% of skills from each category. This approach is justified by:
#
# 1. **Pareto Principle Foundation**: The 80/20 rule suggests that 80% of usage typically comes from 20% of technologies
# 2. **Market Demand Focus**: The top 25% represents the most in-demand, widely-adopted skills in the industry
# 3. **Remote Work Relevance**: Popular technologies are more likely to correlate with remote opportunities due to higher demand, a thriving ecosystem, and being more well-supported.
# 4. **Noise Reduction**: Excludes rarely-used or niche technologies that may introduce noise without meaningful predictive power
#
# **Technology Categories:**
#
# 1. **Programming Languages**: Programming, scripting, and markup languages
#
# 2. **Database Systems**: Database environments
#
# 3. **Cloud Platforms and Infrastructure**: Cloud platforms, containerization/orchestration tools, package managers, build tools, and infrastructure solutions
#
# 4. **Web Frameworks**: Web frameworks and web technologies
#
# 5. **Development Environments**: Development environments and AI-enabled code editing tools
#
# 6. **Collaboration Tools**: Collaborative work management and code documentation tools
#
# 7. **AI Models**: LLM models for AI tools used for development work
#
# **Data Processing:**
#
# Each skill name undergoes standardized cleaning to create valid column names:
# - All text converted to lowercase
# - Spaces converted to underscores
# - Special characters like #, +, / replaced with readable alternatives (sharp, plus, _)
# - Parentheses and hyphens removed or converted
#
# The survey also included binary questions asking whether respondents extensively used each technology category (yes/no/don't know). However, to obtain more relevant data, we focused on the specific technologies used rather than general category participation. As such, these questions were omitted.

# %%
# Programming Languages
language_features = funcs.encode_skills(survey_data, 'LanguageHaveWorkedWith', 'lang', top_perc=100)
# Out:
# Skill Analysis for 'LanguageHaveWorkedWith':
# Unique skills: 42
# Average skills count: 6.14
# Using top 100% = 42 skills out of 42 total
# Skills: ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Bash/Shell (all shells)', 'TypeScript', 'Java', 'C#', 'C++', 'PowerShell', 'C', 'PHP', 'Go', 'Rust', 'Kotlin', 'Lua', 'Assembly', 'Ruby', 'Dart', 'Swift', 'R', 'Groovy', 'Visual Basic (.Net)', 'VBA', 'MATLAB', 'Perl', 'GDScript', 'Elixir', 'Scala', 'Delphi', 'Lisp', 'MicroPython', 'Zig', 'Erlang', 'Fortran', 'Ada', 'F#', 'OCaml', 'Gleam', 'Prolog', 'COBOL', 'Mojo']
#
# Skill features created:
# Shape: (49191, 42)
# ...

# %%
# Database Systems  
database_features = funcs.encode_skills(survey_data, 'DatabaseHaveWorkedWith', 'db', top_perc=100)
# Out:
# Skill Analysis for 'DatabaseHaveWorkedWith':
# Unique skills: 30
# Average skills count: 3.53
# Using top 100% = 30 skills out of 30 total
# Skills: ['PostgreSQL', 'MySQL', 'SQLite', 'Microsoft SQL Server', 'Redis', 'MongoDB', 'MariaDB', 'Elasticsearch', 'Oracle', 'Dynamodb', 'BigQuery', 'Supabase', 'Cloud Firestore', 'H2', 'Firebase Realtime Database', 'Microsoft Access', 'Cosmos DB', 'Snowflake', 'InfluxDB', 'Databricks SQL', 'DuckDB', 'Cassandra', 'Neo4J', 'Valkey', 'Clickhouse', 'IBM DB2', 'Amazon Redshift', 'Cockroachdb', 'Pocketbase', 'Datomic']
#
# Skill features created:
# Shape: (49191, 30)
# ...

# %%
# Cloud Platforms and Infrastructure
platform_features = funcs.encode_skills(survey_data, 'PlatformHaveWorkedWith', 'platform', top_perc=100)
# Out:
# Skill Analysis for 'PlatformHaveWorkedWith':
# Unique skills: 42
# Average skills count: 7.14
# Using top 100% = 42 skills out of 42 total
# Skills: ['Docker', 'npm', 'Amazon Web Services (AWS)', 'Pip', 'Kubernetes', 'Microsoft Azure', 'Homebrew', 'Vite', 'Google Cloud', 'Make', 'Yarn', 'Cloudflare', 'NuGet', 'APT', 'Webpack', 'Terraform', 'Maven (build tool)', 'Gradle', 'Cargo', 'pnpm', 'Firebase', 'Prometheus', 'Ansible', 'Podman', 'Chocolatey', 'Composer', 'MSBuild', 'Digital Ocean', 'Vercel', 'Poetry', 'Datadog', 'Pacman', 'Netlify', 'Bun', 'Supabase', 'Heroku', 'Ninja', 'Splunk', 'New Relic', 'Railway', 'IBM Cloud', 'Yandex Cloud']
#
# Skill features created:
# Shape: (49191, 42)
# ...

# %%
# Web Frameworks
webframe_features = funcs.encode_skills(survey_data, 'WebframeHaveWorkedWith', 'webframe', top_perc=100)
# Out:
# Skill Analysis for 'WebframeHaveWorkedWith':
# Unique skills: 28
# Average skills count: 3.78
# Using top 100% = 28 skills out of 28 total
# Skills: ['Node.js', 'React', 'jQuery', 'Next.js', 'Express', 'ASP.NET Core', 'Angular', 'Vue.js', 'FastAPI', 'Spring Boot', 'Flask', 'ASP.NET', 'WordPress', 'Django', 'Laravel', 'AngularJS', 'Svelte', 'Blazor', 'NestJS', 'Ruby on Rails', 'Astro', 'Deno', 'Symfony', 'Nuxt.js', 'Fastify', 'Axum', 'Phoenix', 'Drupal']
#
# Skill features created:
# Shape: (49191, 28)
# ...

# %%
# Development Environments
devenv_features = funcs.encode_skills(survey_data, 'DevEnvsHaveWorkedWith', 'devenv', top_perc=100)
# Out:
# Skill Analysis for 'DevEnvsHaveWorkedWith':
# Unique skills: 27
# Average skills count: 3.63
# Using top 100% = 27 skills out of 27 total
# Skills: ['Visual Studio Code', 'Visual Studio', 'Notepad++', 'IntelliJ IDEA', 'Vim', 'Cursor', 'PyCharm', 'Android Studio', 'Jupyter Notebook/JupyterLab', 'Neovim', 'Nano', 'Sublime Text', 'Xcode', 'Claude Code', 'WebStorm', 'Zed', 'Rider', 'Eclipse', 'VSCodium', 'PhpStorm', 'Windsurf', 'RustRover', 'Lovable.dev', 'Bolt', 'Cline and/or Roo', 'Aider', 'Trae']
#
# Skill features created:
# Shape: (49191, 27)
# ...

# %%
# Collaboration Tools
collab_features = funcs.encode_skills(survey_data, 'OfficeStackAsyncHaveWorkedWith', 'collab', top_perc=100)
# Out:
# Skill Analysis for 'OfficeStackAsyncHaveWorkedWith':
# Unique skills: 25
# Average skills count: 3.81
# Using top 100% = 25 skills out of 25 total
# Skills: ['GitHub', 'Jira', 'GitLab', 'Markdown File', 'Confluence', 'Azure Devops', 'Notion', 'Obsidian', 'Google Workspace', 'Miro', 'Trello', 'Wikis', 'Google Colab', 'Lucid (includes Lucidchart)', 'Asana', 'Doxygen', 'Clickup', 'Linear', 'Microsoft Planner', 'Monday.com', 'Redmine', 'Airtable', 'YouTrack', 'Stack Overflow for Teams', 'Coda']
#
# Skill features created:
# Shape: (49191, 25)
# ...

# %%
# AI Models
aimodel_features = funcs.encode_skills(survey_data, 'AIModelsHaveWorkedWith', 'aimodel', top_perc=100)
# Out:
# Skill Analysis for 'AIModelsHaveWorkedWith':
# Unique skills: 17
# Average skills count: 3.49
# Using top 100% = 17 skills out of 17 total
# Skills: ['openAI GPT (chatbot models)', 'Anthropic: Claude Sonnet', 'Gemini (Flash general purpose models)', 'openAI Reasoning models', 'openAI Image generating models', 'Gemini (Pro Reasoning models)', 'DeepSeek (R- Reasoning models)', 'Meta Llama (all models)', 'DeepSeek (V- General purpose models)', 'X Grok models', 'Mistral AI models', 'Perplexity Sonar models', 'Alibaba Cloud Qwen models', 'Microsoft Phi-4 models', 'Amazon Titan models', 'Cohere: Command A', 'Reka (Flash 3 or other Reka models)']
#
# Skill features created:
# Shape: (49191, 17)
# ...

# %%
print("Technology Skills Summary")
print(f"Programming Languages: {language_features.shape[1]} features")
print(f"Database Systems: {database_features.shape[1]} features") 
print(f"Cloud/Infrastructure: {platform_features.shape[1]} features")
print(f"Web Frameworks: {webframe_features.shape[1]} features")
print(f"Development Environments: {devenv_features.shape[1]} features")
print(f"Collaboration Tools: {collab_features.shape[1]} features")
print(f"AI Models: {aimodel_features.shape[1]} features")

total_tech_features = (language_features.shape[1] + database_features.shape[1] + 
                      platform_features.shape[1] + webframe_features.shape[1] +
                      devenv_features.shape[1] + collab_features.shape[1] + aimodel_features.shape[1])
print(f"\nTotal Technology Features: {total_tech_features}")
# Out:
# Technology Skills Summary
# Programming Languages: 42 features
# Database Systems: 30 features
# Cloud/Infrastructure: 42 features
# Web Frameworks: 28 features
# Development Environments: 27 features
# Collaboration Tools: 25 features
# AI Models: 17 features
#
# Total Technology Features: 211

# %% [markdown]
# ## **AI Usage**

# %%
ai_industry_use = funcs.encode_skills(survey_data, 'AIAgent_Uses', 'ai_uses', top_perc=100)
# Out:
# Skill Analysis for 'AIAgent_Uses':
# Unique skills: 10
# Average skills count: 1.89
# Using top 100% = 10 skills out of 10 total
# Skills: ['Software engineering', 'Data and analytics', 'IT operations', 'Business process automation', 'Decision intelligence', 'Customer service support', 'Marketing', 'Cybersecurity', 'Robotics', 'Other Industry purpose (write in):']
#
# Skill features created:
# Shape: (49191, 10)
# Columns: ['ai_uses_software_engineering', 'ai_uses_data_and_analytics', 'ai_uses_it_operations', 'ai_uses_business_process_automation', 'ai_uses_decision_intelligence', 'ai_uses_customer_service_support', 'ai_uses_marketing', 'ai_uses_cybersecurity', 'ai_uses_robotics', 'ai_uses_other_industry_purpose_write_in:']
#
# Top 10 skill usage rates:
# software engineering: 20.9%
# data and analytics: 6.2%
# it operations: 4.5%
# business process automation: 4.4%
# decision intelligence: 2.8%
# customer service support: 2.8%
# marketing: 2.2%
# cybersecurity: 1.8%
# robotics: 1.0%
# ...

# %%
# One-hot encode LearnCodeAI answers
compressed_learncodeai = survey_data['LearnCodeAI'].apply(funcs.compress_learncodeai)
learncodeai_encoded = pd.get_dummies(compressed_learncodeai, prefix='learncodeai')

print(f"\nOne-hot encoded yes/no answers to did you learn AI tools in the past year?:")
print(f"Shape: {learncodeai_encoded.shape}")
print(f"Columns: {list(learncodeai_encoded.columns)}")

# Show the compression results
print(f"\nCompressed answer distribution:")
learncodeai_counts = compressed_learncodeai.value_counts()
total_rows = len(compressed_learncodeai)

print(learncodeai_counts)
print(f"Total rows: {total_rows}")
learncodeai_encoded
# Out:
# One-hot encoded yes/no answers to did you learn AI tools in the past year?:
# Shape: (49191, 3)
# Columns: ['learncodeai_no', 'learncodeai_others', 'learncodeai_yes']
#
# Compressed answer distribution:
# LearnCodeAI
# yes       30430
# no        14771
# others     3990
# Name: count, dtype: int64
# Total rows: 49191
#        learncodeai_no  learncodeai_others  learncodeai_yes
# 0               False               False             True
# 1               False               False             True
# 2               False               False             True
# 3               False               False             True
# 4               False               False             True
# ...               ...                 ...              ...
# 49186           False                True            False
# 49187           False               False             True
# 49188           False               False             True
# 49189           False               False             True
# ...

# %%
ai_learn_how = funcs.encode_skills(survey_data, 'AILearnHow', 'ai_learn_how', top_perc=100)
# Out:
# Skill Analysis for 'AILearnHow':
# Unique skills: 13
# Average skills count: 2.87
# Using top 100% = 13 skills out of 13 total
# Skills: ['AI CodeGen tools or AI-enabled apps', 'Other online resources (e.g. standard search, forum, online community)', 'Technical documentation (is generated for/by the tool or system)', 'Videos (not associated with specific online course or certification)', 'Blogs or podcasts', 'Colleague or on-the-job training', 'Stack Overflow or Stack Exchange', 'Online Courses or Certification (includes all media types)', 'Books / Physical media', 'School (i.e., University, College, etc)', 'Other (please specify):', 'Games or coding challenges', 'Coding Bootcamp']
#
# Skill features created:
# Shape: (49191, 13)
# ...

# %%
# One-hot encode AISelect answers
compressed_aiselect = survey_data['AISelect'].apply(funcs.compress_aiselect)
aiselect_encoded = pd.get_dummies(compressed_aiselect, prefix='aiselect')

print(f"\nOne-hot encoded AI use frequency:")
print(f"Shape: {aiselect_encoded.shape}")
print(f"Columns: {list(aiselect_encoded.columns)}")

# Show the compression results
print(f"\nCompressed answer distribution:")
aiselect_counts = compressed_aiselect.value_counts()
total_rows = len(compressed_aiselect)

print(aiselect_counts)
print(f"Total rows: {total_rows}")
aiselect_encoded
# Out:
# One-hot encoded AI use frequency:
# Shape: (49191, 5)
# Columns: ['aiselect_daily', 'aiselect_infrequently', 'aiselect_no', 'aiselect_others', 'aiselect_weekly']
#
# Compressed answer distribution:
# AISelect
# daily           15883
# others          15471
# no               7251
# weekly           5958
# infrequently     4628
# Name: count, dtype: int64
# Total rows: 49191
#        aiselect_daily  aiselect_infrequently  aiselect_no  aiselect_others  \
# 0               False                   True        False            False
# 1               False                  False        False            False
# 2                True                  False        False            False
# 3               False                  False        False            False
# 4               False                  False        False            False
# ...               ...                    ...          ...              ...
# 49186           False                  False        False             True
# ...

# %%
# One-hot encode AIAgents answers
compressed_aiagents = survey_data['AIAgents'].apply(funcs.compress_aiagents)
aiagents_encoded = pd.get_dummies(compressed_aiagents, prefix='aiagents')

print(f"\nOne-hot encoded AI agents:")
print(f"Shape: {aiagents_encoded.shape}")
print(f"Columns: {list(aiagents_encoded.columns)}")

# Show the compression results
print(f"\nCompressed answer distribution:")
aiagents_counts = compressed_aiagents.value_counts()
total_rows = len(compressed_aiagents)

print(aiagents_counts)
print(f"Total rows: {total_rows}")
aiagents_encoded
# Out:
# One-hot encoded AI agents:
# Shape: (49191, 5)
# Columns: ['aiagents_daily', 'aiagents_monthly', 'aiagents_no', 'aiagents_others', 'aiagents_weekly']
#
# Compressed answer distribution:
# AIAgents
# no         22044
# others     17272
# daily       4509
# weekly      2868
# monthly     2498
# Name: count, dtype: int64
# Total rows: 49191
#        aiagents_daily  aiagents_monthly  aiagents_no  aiagents_others  \
# 0               False              True        False            False
# 1               False             False         True            False
# 2               False             False        False            False
# 3               False              True        False            False
# 4               False             False         True            False
# ...               ...               ...          ...              ...
# 49186           False             False        False             True
# 49187           False             False        False             True
# ...

# %%
# One-hot encode AIAgentChange answers
compressed_aiagentchange = survey_data['AIAgentChange'].apply(funcs.compress_aiagentchange)
aiagentchange_encoded = pd.get_dummies(compressed_aiagentchange, prefix='aiagentchange')

print(f"\nOne-hot encoded AI agent change:")
print(f"Shape: {aiagentchange_encoded.shape}")
print(f"Columns: {list(aiagentchange_encoded.columns)}")

# Show the compression results
print(f"\nCompressed answer distribution:")
aiagentchange_counts = compressed_aiagentchange.value_counts()
total_rows = len(compressed_aiagentchange)

print(aiagentchange_counts)
print(f"Total rows: {total_rows}")
aiagentchange_encoded
# Out:
# One-hot encoded AI agent change:
# Shape: (49191, 5)
# Columns: ['aiagentchange_no', 'aiagentchange_others', 'aiagentchange_yes_greatly', 'aiagentchange_yes_minimally', 'aiagentchange_yes_somewhat']
#
# Compressed answer distribution:
# AIAgentChange
# others           17513
# yes_minimally    13097
# yes_somewhat     12581
# yes_greatly       5178
# no                 822
# Name: count, dtype: int64
# Total rows: 49191
#        aiagentchange_no  aiagentchange_others  aiagentchange_yes_greatly  \
# 0                 False                 False                      False
# 1                 False                 False                      False
# 2                 False                 False                      False
# 3                 False                 False                      False
# 4                 False                 False                       True
# ...                 ...                   ...                        ...
# ...

# %% [markdown]
# ### Note: these have a low adoption % could be removed after doing a chi square or whatever correlation check. If they are not useful, then lets chop them off. For now, I will leave them.

# %%
ai_technical_use = funcs.encode_skills(survey_data, 'AgentUsesGeneral', 'ai_uses_technical', top_perc=100)
# Out:
# Skill Analysis for 'AgentUsesGeneral':
# Unique skills: 8
# Average skills count: 2.15
# Using top 100% = 8 skills out of 8 total
# Skills: ['Language processing', 'Integration with external agents and APIs', 'MCP servers', 'Agent/multi-agent orchestration', 'Vector databases for AI applications', 'Multi-platform search enablement', 'Personalized agent creation', 'Other specific task (write in):']
#
# Skill features created:
# Shape: (49191, 8)
# Columns: ['ai_uses_technical_language_processing', 'ai_uses_technical_integration_with_external_agents_and_apis', 'ai_uses_technical_mcp_servers', 'ai_uses_technical_agent_multi_agent_orchestration', 'ai_uses_technical_vector_databases_for_ai_applications', 'ai_uses_technical_multi_platform_search_enablement', 'ai_uses_technical_personalized_agent_creation', 'ai_uses_technical_other_specific_task_write_in:']
#
# Top 8 skill usage rates:
# language processing: 5.8%
# integration with external agents and apis: 4.5%
# mcp servers: 4.1%
# ...

# %%
# AI Agent Knowledge - Tools for AI agent memory or data management
ai_knowledge = funcs.encode_skills(survey_data, 'AIAgentKnowledge', 'ai_knowledge', top_perc=100)
# Out:
# Skill Analysis for 'AIAgentKnowledge':
# Unique skills: 16
# Average skills count: 2.09
# Using top 100% = 16 skills out of 16 total
# Skills: ['Redis', 'GitHub MCP Server', 'supabase', 'ChromaDB', 'pgvector', 'Neo4j', 'Pinecone', 'Qdrant', 'Milvus', 'Fireproof', 'LangMem', 'Weaviate', 'LanceDB', 'mem0', 'Zep', 'Letta']
#
# Skill features created:
# Shape: (49191, 16)
# Columns: ['ai_knowledge_redis', 'ai_knowledge_github_mcp_server', 'ai_knowledge_supabase', 'ai_knowledge_chromadb', 'ai_knowledge_pgvector', 'ai_knowledge_neo4j', 'ai_knowledge_pinecone', 'ai_knowledge_qdrant', 'ai_knowledge_milvus', 'ai_knowledge_fireproof', 'ai_knowledge_langmem', 'ai_knowledge_weaviate', 'ai_knowledge_lancedb', 'ai_knowledge_mem0', 'ai_knowledge_zep', 'ai_knowledge_letta']
#
# Top 16 skill usage rates:
# redis: 3.0%
# github mcp server: 3.0%
# supabase: 1.4%
# chromadb: 1.4%
# pgvector: 1.2%
# neo4j: 0.9%
# pinecone: 0.8%
# qdrant: 0.6%
# milvus: 0.4%
# fireproof: 0.3%
# langmem: 0.3%
# ...

# %%
# AI Agent Orchestration - Tools for AI agent orchestration or agent frameworks
ai_orchestration = funcs.encode_skills(survey_data, 'AIAgentOrchestration', 'ai_orchestration', top_perc=100)
# Out:
# Skill Analysis for 'AIAgentOrchestration':
# Unique skills: 19
# Average skills count: 2.19
# Using top 100% = 19 skills out of 19 total
# Skills: ['Ollama', 'LangChain', 'LangGraph', 'Vertex AI', 'Amazon Bedrock Agents', 'OpenRouter', 'Llama Index', 'AutoGen (Microsoft)', 'Zapier', 'CrewAI', 'Semantic Kernel', 'IBM watsonx.ai', 'Haystack', 'Smolagents', 'Agno', 'phidata', 'Smol-AGI', 'Martian', 'lyzr']
#
# Skill features created:
# Shape: (49191, 19)
# ...

# %%
# AI Agent Observability - Tools for AI agent observability, monitoring or security
ai_observe_secure = funcs.encode_skills(survey_data, 'AIAgentObserveSecure', 'ai_observe', top_perc=100)
# Out:
# Skill Analysis for 'AIAgentObserveSecure':
# Unique skills: 16
# Average skills count: 1.77
# Using top 100% = 16 skills out of 16 total
# Skills: ['Grafana + Prometheus', 'Sentry', 'Snyk', 'New Relic', 'LangSmith', 'Honeycomb', 'Langfuse', 'Wiz', 'Galileo', 'Adversarial Robustness Toolbox (ART)', 'Protect AI', 'Vectra AI', 'arize', 'helicone', 'Metero', 'opik']
#
# Skill features created:
# Shape: (49191, 16)
# Columns: ['ai_observe_grafana_plus_prometheus', 'ai_observe_sentry', 'ai_observe_snyk', 'ai_observe_new_relic', 'ai_observe_langsmith', 'ai_observe_honeycomb', 'ai_observe_langfuse', 'ai_observe_wiz', 'ai_observe_galileo', 'ai_observe_adversarial_robustness_toolbox_art', 'ai_observe_protect_ai', 'ai_observe_vectra_ai', 'ai_observe_arize', 'ai_observe_helicone', 'ai_observe_metero', 'ai_observe_opik']
#
# Top 16 skill usage rates:
# grafana plus prometheus: 2.4%
# sentry: 1.7%
# snyk: 1.0%
# new relic: 0.7%
# langsmith: 0.7%
# honeycomb: 0.5%
# langfuse: 0.5%
# wiz: 0.4%
# ...

# %%
# AI Agent External - Out-of-the-box agents, copilots or assistants
ai_external = funcs.encode_skills(survey_data, 'AIAgentExternal', 'ai_external', top_perc=100)
# Out:
# Skill Analysis for 'AIAgentExternal':
# Unique skills: 20
# Average skills count: 3.45
# Using top 100% = 20 skills out of 20 total
# Skills: ['ChatGPT', 'GitHub Copilot', 'Google Gemini', 'Claude Code', 'Microsoft Copilot', 'Perplexity', 'v0.dev', 'Bolt.new', 'Lovable.dev', 'AgentGPT', 'Tabnine', 'Replit', 'Auto-GPT', 'Amazon Codewhisperer', 'Blackbox AI', 'Roo code (Roo-Cline)', 'Cody', 'Devin AI', 'Glean (Enterprise Agents)', 'OpenHands (formerly OpenDevin)']
#
# Skill features created:
# Shape: (49191, 20)
# ...

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**
#
# This section explores the relationships between various features and remote work arrangements to identify key predictors and patterns that will inform our machine learning model.
#
# ## **Goals:**
# 1. Understand the distribution and characteristics of remote vs non-remote workers
# 2. Identify features with strong associations to remote work
# 3. Detect multicollinearity and data quality issues
# 4. Generate insights for feature engineering and model selection
#
# ---

# %% [markdown]
# ### **Target Data**
#
# The distribution is somewhat imbalanced, but a decent proportion of workers are remote, showing that while uncommon, it is achievable and realistic for most developers.

# %%
target_counts = target.value_counts()
total = len(target)

print(f"Non-Remote/Inflexible: {target_counts[0]:,} ({target_counts[0]/total*100:.2f}%)")
print(f"Remote/Flexible: {target_counts[1]:,} ({target_counts[1]/total*100:.2f}%)")
print(f"\nData Ratio: {target_counts[0]/target_counts[1]:.2f}:1")

fig = go.Figure()
fig.add_trace(go.Bar(
    x=['Non-Remote/Inflexible', 'Remote/Flexible'],
    y=[target_counts[0], target_counts[1]],
    text=[f"({target_counts[0]/total*100:.2f}%)", 
          f"({target_counts[1]/total*100:.2f}%)"],
    textposition='auto',
    marker_color=[funcs.get_color('Non-Remote/Inflexible'), 
                  funcs.get_color('Remote/Flexible')]
))

fig.update_layout(
    title='Distribution of Work Arrangement Types',
    xaxis_title='Work Arrangement',
    yaxis_title='Number of Respondents',
    template='plotly_white',
    height=500
)

fig.show()
# Out:
# Non-Remote/Inflexible: 34,016 (69.15%)
# Remote/Flexible: 15,175 (30.85%)
#
# Data Ratio: 2.24:1

# %% [markdown]
# ### **Age Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that age is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that age group should be included as a feature in the predictive model, as it provides meaningful information.
#
# #### **Data Interpretation**
# It appears that age isn't a major barrier and the group ratios are balanced and comparable with 25-34 years old and 35-44 years old having the most given that those are the prime working years. The data may be show generational differences, such as older developers being less likely to be in remote arrangements, showing a preference for in-office workplaces.

# %%
age_remote = pd.DataFrame({
    'Age': survey_data['Age'],
    'RemoteWork': target
})

age_remote = age_remote.dropna(subset=['Age'])

age_stats = age_remote.groupby('Age').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()

age_stats.columns = ['Age', 'Remote_Count', 'Total_Count', 'Remote_Rate']
age_stats = age_stats.sort_values('Remote_Rate', ascending=False)

print("Age Groups and Remote Work Rates")
print(age_stats.to_string(index=False))

contingency_table = pd.crosstab(age_remote['Age'], age_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

fig = go.Figure()

age_order = ['18-24 years old', '25-34 years old', '35-44 years old', '45-54 years old', 
             '55-64 years old', '65 years or older', 'Under 18 years old', 'Prefer not to say']
age_order = [age for age in age_order if age in age_stats['Age'].values]

age_colors = [funcs.get_color(age) for age in age_order]

for i, age in enumerate(age_order):
    row = age_stats[age_stats['Age'] == age].iloc[0]
    remote = row['Remote_Count']
    non_remote = row['Total_Count'] - remote
    
    fig.add_trace(go.Bar(
        name=age,
        x=['Remote/Flexible', 'Non-Remote/Inflexible'],
        y=[remote, non_remote],
        text=[f"{remote:,}", f"{non_remote:,}"],
        textposition='auto',
        marker_color=age_colors[i]
    ))

fig.update_layout(
    title='Work Arrangement by Age Group',
    xaxis_title='Work Arrangement',
    yaxis_title='Number of Respondents',
    barmode='group',
    template='plotly_white',
    height=600,
    legend_title_text='Age Group'
)

fig.show()

fig2 = px.bar(age_stats, x='Age', y='Remote_Rate', 
              title='Remote Work Rate by Age Group',
              labels={'Remote_Rate': 'Remote Work Rate', 'Age': 'Age Group'},
              text=age_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
              color='Age',
              color_discrete_map={age: funcs.get_color(age) for age in age_stats['Age']})
fig2.update_traces(textposition='outside')
fig2.update_layout(template='plotly_white', height=500)
fig2.show()
# Out:
# Age Groups and Remote Work Rates
#               Age  Remote_Count  Total_Count  Remote_Rate
#   35-44 years old          5049        13241     0.381316
#   45-54 years old          2272         6275     0.362072
#   55-64 years old           839         2626     0.319497
#   25-34 years old          5154        16519     0.312004
# 65 years or older           214          942     0.227176
#   18-24 years old          1605         9210     0.174267
# Prefer not to say            42          378     0.111111
#
# Chi-Square Test:
#   X² = 1292.1275
#   p-value = 5.4820e-276
#   Significant: Yes

# %% [markdown]
# ### **Education Level Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that education level is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that it should be included as a feature in the predictive model, as it provides meaningful information.
#
# #### **Data Interpretation**
# The data shows that the remote work rates increase after at least being college-educated with associate degrees having the highest rates. Interestingly, the advantage of a higher education is modest, showing that at least having a college degree is a major advantage. Interestingly, the highest education such as professionals have a lower rate, which may indicate requiring their physical presence for their work. But overall, the advantage plateaus after an associate degree.

# %%
edu_remote = pd.DataFrame({
    'Education': compressed_education,
    'RemoteWork': target
})

edu_stats = edu_remote.groupby('Education').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
edu_stats.columns = ['Education', 'Remote_Count', 'Total_Count', 'Remote_Rate']
edu_stats = edu_stats.sort_values('Remote_Rate', ascending=False)

print("Education Level and Remote Work Rates")
print(edu_stats.to_string(index=False))

contingency_table = pd.crosstab(edu_remote['Education'], edu_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

edu_colors = {edu: funcs.get_color(edu) for edu in edu_stats['Education']}

fig = px.bar(edu_stats, x='Education', y='Remote_Rate',
             title='Remote Work Rate by Education Level',
             labels={'Remote_Rate': 'Remote Work Rate', 'Education': 'Education Level'},
             text=edu_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='Education',
             color_discrete_map=edu_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig.show()

fig2 = go.Figure()
for edu in edu_stats['Education']:
    row = edu_stats[edu_stats['Education'] == edu].iloc[0]
    remote = row['Remote_Count']
    non_remote = row['Total_Count'] - remote
    
    fig2.add_trace(go.Bar(
        name=edu,
        x=['Remote/Flexible', 'Non-Remote/Inflexible'],
        y=[remote, non_remote],
        text=[f"{remote:,}", f"{non_remote:,}"],
        textposition='auto',
        marker_color=edu_colors[edu]
    ))

fig2.update_layout(
    title='Work Arrangement by Education Level',
    xaxis_title='Work Arrangement',
    yaxis_title='Number of Respondents',
    barmode='group',
    template='plotly_white',
    height=600,
    legend_title_text='Education Level'
)
fig2.show()
# Out:
# Education Level and Remote Work Rates
#                      Education  Remote_Count  Total_Count  Remote_Rate
#                      associate           528         1562     0.338028
#                       bachelor          6728        20278     0.331788
#                         master          4159        12589     0.330368
# went to college without degree          1923         6182     0.311064
#                   professional           774         2624     0.294970
#               secondary school           787         3631     0.216745
#                 primary school           104          582     0.178694
#                          other           172         1743     0.098680
#
# Chi-Square Test:
#   X² = 637.5770
#   p-value = 1.9611e-133
#   Significant: Yes

# %% [markdown]
# ### **Employment Status Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that employment status is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that it should be included as a feature in the predictive model, as it provides meaningful information.
#
# #### **Data Interpretation**
# The data shows clear differences in remote work rates across employment groups. Employed respondents have suggesting that they are the most able to adopt remote work. While those that aren't formally employed have the lowest rates.

# %%
employ_remote = pd.DataFrame({
    'Employment': compressed_employment,
    'RemoteWork': target
})

# Filter out 'others' category
employ_remote = employ_remote[employ_remote['Employment'] != 'others']

employ_stats = employ_remote.groupby('Employment').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
employ_stats.columns = ['Employment', 'Remote_Count', 'Total_Count', 'Remote_Rate']
employ_stats = employ_stats.sort_values('Remote_Rate', ascending=False)

print("Employment Status and Remote Work Rates")
print(employ_stats.to_string(index=False))

contingency_table = pd.crosstab(employ_remote['Employment'], employ_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

employ_colors = {emp: funcs.get_color(emp) for emp in employ_stats['Employment']}

fig = px.bar(employ_stats, x='Employment', y='Remote_Rate',
             title='Remote Work Rate by Employment Status',
             labels={'Remote_Rate': 'Remote Work Rate', 'Employment': 'Employment Status'},
             text=employ_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='Employment',
             color_discrete_map=employ_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig.show()
# Out:
# Employment Status and Remote Work Rates
#  Employment  Remote_Count  Total_Count  Remote_Rate
#    employed         12821        33750     0.379881
# independent          1751         6708     0.261032
#     student           421         4428     0.095077
#     retired            54          708     0.076271
#  unemployed           128         2227     0.057476
#
# Chi-Square Test:
#   X² = 2601.4654
#   p-value = 0.0000e+00
#   Significant: Yes

# %% [markdown]
# ### **Current Profession Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that professional status is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that it should be included as a feature in the predictive model, as it provides meaningful information.
#
# #### **Data Interpretation**
# The data shows that professional developers have the highest remote work rate at about 35%, reflecting that development roles are particularly well-suited to remote arrangements. Retired or non-developers and non-primary developers both have moderate remote work rates, suggesting that even those not primarily focused on development still engage in remote work at a substantial level. Meanwhile, learners or hobbyists have a much lower remote work rate at about 9%, which makes sense since this group is less likely to be in formal employment. Overall, it shows that being a professional developer is a major advantage.

# %%
prof_remote = pd.DataFrame({
    'Profession': current_profession,
    'RemoteWork': target
})

prof_stats = prof_remote.groupby('Profession').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
prof_stats.columns = ['Profession', 'Remote_Count', 'Total_Count', 'Remote_Rate']
prof_stats = prof_stats.sort_values('Remote_Rate', ascending=False)

print("Current Profession and Remote Work Rates")
print(prof_stats.to_string(index=False))

contingency_table = pd.crosstab(prof_remote['Profession'], prof_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

prof_colors = {prof: funcs.get_color(prof) for prof in prof_stats['Profession']}

fig = px.bar(prof_stats, x='Profession', y='Remote_Rate',
             title='Remote Work Rate by Current Profession',
             labels={'Remote_Rate': 'Remote Work Rate', 'Profession': 'Profession Type'},
             text=prof_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='Profession',
             color_discrete_map=prof_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig.show()
# Out:
# Current Profession and Remote Work Rates
#          Profession  Remote_Count  Total_Count  Remote_Rate
#    professional dev         13162        37467     0.351296
#  retired or non-dev           523         2321     0.225334
#     non-primary dev          1096         4894     0.223948
# learner or hobbyist           394         4509     0.087381
#
# Chi-Square Test:
#   X² = 1594.3924
#   p-value = 0.0000e+00
#   Significant: Yes

# %% [markdown]
# ### **Developer Type Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that developer type is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that it should be included as a feature in the predictive model, as it provides meaningful information.
#
# #### **Data Interpretation**
# The data shows a gradient in remote work rates across different developer roles. Roles that are heavily software-focused, such as backend developers, frontend developers, and mobile developers, have the highest remote work rates, suggesting these jobs are particularly well-suited to distributed work. Architecture and QA roles also show high remote participation at around 40%, while full-stack developers remain high at roughly 38.7%. Managerial, DevOps, security, and UX roles sit in the mid-range, indicating that coordination-heavy roles still support remote work, although slightly less. More specialized or hardware-adjacent roles, such as database specialists, game developers, AI/ML developers, and data specialists, drop into the low 30% range, possibly because of infrastructure constraints. The lowest remote work rates appear among support/analyst, embedded developers, and especially researchers/scientists showing a more common need to be on-site. While students, retirees, and others have the lowest rates.

# %%
devtype_remote = pd.DataFrame({
    'DevType': compressed_devtype,
    'RemoteWork': target
})

# Filter out 'others' category
devtype_remote = devtype_remote[devtype_remote['DevType'] != 'others']

devtype_stats = devtype_remote.groupby('DevType').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
devtype_stats.columns = ['DevType', 'Remote_Count', 'Total_Count', 'Remote_Rate']
devtype_stats = devtype_stats.sort_values('Remote_Rate', ascending=False)

print("Developer Type and Remote Work Rates")
print(devtype_stats.to_string(index=False))

contingency_table = pd.crosstab(devtype_remote['DevType'], devtype_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

devtype_colors = {dev: funcs.get_color(dev) for dev in devtype_stats['DevType']}

fig = px.bar(devtype_stats, x='DevType', y='Remote_Rate',
             title='Remote Work Rate by Developer Type (All Types)',
             labels={'Remote_Rate': 'Remote Work Rate', 'DevType': 'Developer Type'},
             text=devtype_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='DevType',
             color_discrete_map=devtype_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=700, xaxis_tickangle=-45, showlegend=False)
fig.show()

fig_counts = go.Figure()
for dev in devtype_stats['DevType']:
    row = devtype_stats[devtype_stats['DevType'] == dev].iloc[0]
    remote = int(row['Remote_Count'])
    non_remote = int(row['Total_Count'] - row['Remote_Count'])

    fig_counts.add_trace(go.Bar(
        name=dev,
        x=['Remote/Flexible', 'Non-Remote/Inflexible'],
        y=[remote, non_remote],
        text=[f"{remote:,}", f"{non_remote:,}"],
        textposition='auto',
        marker_color=devtype_colors[dev]
    ))

fig_counts.update_layout(
    title='Work Arrangement by Developer Type (Counts)',
    xaxis_title='Work Arrangement',
    yaxis_title='Number of Respondents',
    barmode='group',
    template='plotly_white',
    height=900,
    legend_title_text='Developer Type'
)
fig_counts.show()
# Out:
# Developer Type and Remote Work Rates
#               DevType  Remote_Count  Total_Count  Remote_Rate
#     backend developer          2824         6453     0.437626
#    frontend developer           856         1974     0.433637
#      mobile developer           582         1391     0.418404
#    software architect          1096         2684     0.408346
#             qa tester           137          343     0.399417
#  full-stack developer          4778        12351     0.386851
#      executive/leader           359          959     0.374348
#   security specialist           137          370     0.370270
#               manager           579         1575     0.367619
# devops/infrastructure           723         1974     0.366261
#        ux/ui designer            41          115     0.356522
#   database specialist            61          175     0.348571
#        game developer           157          451     0.348115
#       ai/ml developer           306          913     0.335159
# ...

# %% [markdown]
# ### **Organization Size Distribution**
#
# #### **Statistically Significant**
# Although the Spearman correlation indicates a statistically significant with a low positive relationship between organization size and remote work rate (p < 0.05, corr ≈ 0.30), this association appears to be strongly caused by the inclusion of freelancers and solo workers, who show exceptionally high remote work rates. When focusing only on organizations, the remote work rate is relatively flat or even slightly decreasing as organization size increases, suggesting that the overall correlation may be driven primarily by this outlier group. Without the freelancer category, the relationship would likely be much weaker and possibly not meaningful.
#
# #### **Data Interpretation**
# The data shows that the highest remote work rate appears among solo workers or freelancers, with almost 72% working remotely, which makes sense since this group largely defines their own work arrangements. Small organizations also show relatively high remote work rates, but as organization size increases, the remote work rate gradually declines. This suggests that while remote work is fairly common across all company sizes, smaller and more flexible organizations are more likely to adopt it, while larger organizations may face more on-site coordination.

# %%
orgsize_remote = pd.DataFrame({
    'OrgSize': org_size_ordinal,
    'OrgSize_Label': survey_data['OrgSize'],
    'RemoteWork': target
})

orgsize_remote_clean = orgsize_remote.dropna(subset=['OrgSize'])

orgsize_stats = orgsize_remote_clean.groupby(['OrgSize', 'OrgSize_Label']).agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
orgsize_stats.columns = ['OrgSize', 'OrgSize_Label', 'Remote_Count', 'Total_Count', 'Remote_Rate']
orgsize_stats = orgsize_stats.sort_values('OrgSize')

print("Organization Size and Remote Work Rates")
print(orgsize_stats[['OrgSize_Label', 'Remote_Count', 'Total_Count', 'Remote_Rate']].to_string(index=False))

corr, p_value = spearmanr(orgsize_remote_clean['OrgSize'], orgsize_remote_clean['RemoteWork'])
print(f"\nSpearman Correlation:")
print(f"  correlation coefficient = {corr:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")
print(f"  Interpretation: {'Positive' if corr > 0 else 'Negative'} correlation")

orgsize_colors = {size: funcs.get_color(size) for size in orgsize_stats['OrgSize_Label']}

# Line Graph this time
fig = px.line(orgsize_stats, x='OrgSize', y='Remote_Rate',
              title='Remote Work Rate by Organization Size',
              labels={'Remote_Rate': 'Remote Work Rate', 'OrgSize': 'Organization Size (Ordinal)'},
              markers=True,
              text=orgsize_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'))
fig.update_traces(textposition='top center', marker=dict(size=12))
fig.update_layout(template='plotly_white', height=500)
fig.show()

fig2 = px.bar(orgsize_stats, x='OrgSize_Label', y='Remote_Rate',
              title='Remote Work Rate by Organization Size',
              labels={'Remote_Rate': 'Remote Work Rate', 'OrgSize_Label': 'Organization Size'},
              text=orgsize_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
              color='OrgSize_Label',
              color_discrete_map=orgsize_colors)
fig2.update_traces(textposition='outside')
fig2.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig2.show()
# Out:
# Organization Size and Remote Work Rates
#                                      OrgSize_Label  Remote_Count  Total_Count  Remote_Rate
#                                       I don’t know           392          932     0.420601
# Just me - I am a freelancer, sole proprietor, etc.          1264         1763     0.716960
#                             Less than 20 employees          2667         5600     0.476250
#                                 20 to 99 employees          2950         6688     0.441089
#                               100 to 499 employees          2729         6109     0.446718
#                               500 to 999 employees          1036         2361     0.438797
#                           1,000 to 4,999 employees          1667         4156     0.401107
#                           5,000 to 9,999 employees           611         1604     0.380923
#                           10,000 or more employees          1839         4965     0.370393
#
# Spearman Correlation:
# ...

# %% [markdown]
# ### **Geographic Regions Distribution**
#
# #### **Statistically Significant**
# The chi-square test confirms that geographic region is a statistically significant factor in predicting remote work arrangements (p < 0.05). This indicates that it should be included as a feature in the predictive model, as it provides meaningful information. But it is worth noting that there are outlier groups that skew the remote rates.
#
# #### **Data Interpretation**
# The data shows substantial variation in remote work rates across regions. The pattern suggests that remote work is unevenly distributed across the globe, where first-wolrd regions such as the Americas and parts of Europe showing higher adoption while third-world regions such as Africa and Asia lagging behind.

# %%
geo_remote = pd.DataFrame({
    'Region': geographic_regions,
    'RemoteWork': target
})

# Filter out 'other' category
geo_remote = geo_remote[geo_remote['Region'] != 'other']

geo_stats = geo_remote.groupby('Region').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
geo_stats.columns = ['Region', 'Remote_Count', 'Total_Count', 'Remote_Rate']
geo_stats = geo_stats.sort_values('Remote_Rate', ascending=False)

print("Geographic Region and Remote Work Rates")
print(geo_stats.to_string(index=False))

contingency_table = pd.crosstab(geo_remote['Region'], geo_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

geo_colors = {region: funcs.get_color(region) for region in geo_stats['Region']}

fig = px.bar(geo_stats, x='Region', y='Remote_Rate',
             title='Remote Work Rate by Geographic Region',
             labels={'Remote_Rate': 'Remote Work Rate', 'Region': 'Geographic Region'},
             text=geo_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='Region',
             color_discrete_map=geo_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45)
fig.show()

fig2 = go.Figure()
for region in geo_stats['Region']:
    row = geo_stats[geo_stats['Region'] == region].iloc[0]
    remote = row['Remote_Count']
    non_remote = row['Total_Count'] - remote
    
    fig2.add_trace(go.Bar(
        name=region,
        x=['Remote/Flexible', 'Non-Remote/Inflexible'],
        y=[remote, non_remote],
        text=[f"{remote:,}", f"{non_remote:,}"],
        textposition='auto',
        marker_color=geo_colors[region]
    ))

fig2.update_layout(
    title='Work Arrangement by Geographic Region',
    xaxis_title='Work Arrangement',
    yaxis_title='Number of Respondents',
    barmode='group',
    template='plotly_white',
    height=700,
    legend_title_text='Geographic Region'
)
fig2.show()
# Out:
# Geographic Region and Remote Work Rates
#                Region  Remote_Count  Total_Count  Remote_Rate
#         south_america           772         1610     0.479503
#        eastern_europe          1714         3816     0.449161
#      northern_america          3797         8538     0.444718
#       central_america           171          388     0.440722
#          central_asia            23           59     0.389831
#       southern_europe           898         2333     0.384912
#             caribbean            21           61     0.344262
# australia_new_zealand           363         1064     0.341165
#       southern_africa            98          303     0.323432
#        western_africa            89          282     0.315603
#        western_europe          2702         8852     0.305242
#       northern_europe           449         1669     0.269023
#       northern_africa            79          295     0.267797
# ...

# %% [markdown]
# ### **Coding and Professional Years of Experience Distribution**
#
# #### **Statistically Significant**
# The Mann–Whitney U tests show statistically significant differences between remote and non-remote workers for both professional work experience and total coding experience (p < 0.05 for both). This indicates that experience level is meaningfully associated with remote work status, with remote workers tending to have higher experience than non-remote workers.
#
# #### **Data Interpretation**
# Remote workers report slightly higher levels of experience than non-remote workers in both measures. For professional work experience, remote workers have a higher mean (14.13 vs 13.14 years) and a higher median (12 vs 10 years). A similar pattern appears for total coding experience, where remote workers again show higher mean (18.05 vs 16.84 years) and median (15 vs 14 years) values.

# %%
exp_remote = pd.DataFrame({
    'WorkExp': work_years,
    'YearsCode': learn_years,
    'RemoteWork': target
})

# Remove NaN values and unrealistic outliers (e.g., joke answers like 120 years)
# Keep only realistic ranges: 0 to 60 years at most
exp_remote_clean = exp_remote.dropna()
exp_remote_clean = exp_remote_clean[
    (exp_remote_clean['WorkExp'] >= 0) & (exp_remote_clean['WorkExp'] <= 60) &
    (exp_remote_clean['YearsCode'] >= 0) & (exp_remote_clean['YearsCode'] <= 60)
]

remote_workers = exp_remote_clean[exp_remote_clean['RemoteWork'] == 1]
non_remote_workers = exp_remote_clean[exp_remote_clean['RemoteWork'] == 0]

print("Years of Experience and Remote Work")
print("\nWork Experience:")
print(f"Remote Workers - Mean: {remote_workers['WorkExp'].mean():.2f}, Median: {remote_workers['WorkExp'].median():.2f}")
print(f"Non-Remote Workers - Mean: {non_remote_workers['WorkExp'].mean():.2f}, Median: {non_remote_workers['WorkExp'].median():.2f}")

print("\nTotal Coding Experience:")
print(f"Remote Workers - Mean: {remote_workers['YearsCode'].mean():.2f}, Median: {remote_workers['YearsCode'].median():.2f}")
print(f"Non-Remote Workers - Mean: {non_remote_workers['YearsCode'].mean():.2f}, Median: {non_remote_workers['YearsCode'].median():.2f}")

# We will do Mann-Whitney U tests since it is probably not normally distributed
stat_work, p_work = mannwhitneyu(remote_workers['WorkExp'], non_remote_workers['WorkExp'], alternative='two-sided')
stat_code, p_code = mannwhitneyu(remote_workers['YearsCode'], non_remote_workers['YearsCode'], alternative='two-sided')

print("\nMann-Whitney U Tests:")
print("Work Experience:")
print(f"U-stat = {stat_work:.4f}")
print(f"p-value = {p_work:.4e}")
print(f"Significant: {'Yes' if p_work < 0.05 else 'No'}")

print("\nTotal Coding Experience:")
print(f"U-stat = {stat_code:.4f}")
print(f"p-value = {p_code:.4e}")
print(f"Significant: {'Yes' if p_code < 0.05 else 'No'}")

remote_color = funcs.get_color('Remote/Flexible')
non_remote_color = funcs.get_color('Non-Remote/Inflexible')

fig = go.Figure()
fig.add_trace(go.Box(y=remote_workers['WorkExp'], name='Remote/Flexible', marker_color=remote_color))
fig.add_trace(go.Box(y=non_remote_workers['WorkExp'], name='Non-Remote/Inflexible', marker_color=non_remote_color))
fig.update_layout(
    title='Professional Work Experience by Work Arrangement',
    yaxis_title='Years of Professional Experience',
    template='plotly_white',
    height=500
)
fig.show()

fig2 = go.Figure()
fig2.add_trace(go.Box(y=remote_workers['YearsCode'], name='Remote/Flexible', marker_color=remote_color))
fig2.add_trace(go.Box(y=non_remote_workers['YearsCode'], name='Non-Remote/Inflexible', marker_color=non_remote_color))
fig2.update_layout(
    title='Total Coding Experience by Work Arrangement',
    yaxis_title='Years of Coding Experience',
    template='plotly_white',
    height=500
)
fig2.show()

fig3 = go.Figure()
fig3.add_trace(go.Histogram(x=remote_workers['WorkExp'], name='Remote/Flexible', 
                            opacity=0.7, marker_color=remote_color, nbinsx=30))
fig3.add_trace(go.Histogram(x=non_remote_workers['WorkExp'], name='Non-Remote/Inflexible', 
                            opacity=0.7, marker_color=non_remote_color, nbinsx=30))
fig3.update_layout(
    title='Distribution of Professional Work Experience',
    xaxis_title='Years of Professional Experience',
    yaxis_title='Frequency',
    barmode='overlay',
    template='plotly_white',
    height=500
)
fig3.show()

fig4 = go.Figure()
fig4.add_trace(go.Histogram(x=remote_workers['YearsCode'], name='Remote/Flexible', 
                            opacity=0.7, marker_color=remote_color, nbinsx=30))
fig4.add_trace(go.Histogram(x=non_remote_workers['YearsCode'], name='Non-Remote/Inflexible', 
                            opacity=0.7, marker_color=non_remote_color, nbinsx=30))
fig4.update_layout(
    title='Distribution of Total Coding Experience',
    xaxis_title='Years of Coding Experience',
    yaxis_title='Frequency',
    barmode='overlay',
    template='plotly_white',
    height=500
)
fig4.show()

fig_combined = make_subplots(
    rows=1, cols=2,
    subplot_titles=(
        'Work Experience Distribution',
        'Coding Experience Distribution'
    ),
    horizontal_spacing=0.15
)

# Create KDE curves for Work Experience
x_work = np.linspace(exp_remote_clean['WorkExp'].min(), exp_remote_clean['WorkExp'].max(), 200)
kde_remote_work = gaussian_kde(remote_workers['WorkExp'].dropna())

fig_combined.add_trace(
    go.Scatter(x=x_work, y=kde_remote_work(x_work), name='Remote/Flexible', 
               mode='lines', line=dict(color=remote_color, width=3)),
    row=1, col=1
)

# Create KDE curves for Coding Experience
x_code = np.linspace(exp_remote_clean['YearsCode'].min(), exp_remote_clean['YearsCode'].max(), 200)
kde_remote_code = gaussian_kde(remote_workers['YearsCode'].dropna())

fig_combined.add_trace(
    go.Scatter(x=x_code, y=kde_remote_code(x_code), name='Remote/Flexible', 
               mode='lines', line=dict(color=remote_color, width=3), showlegend=False),
    row=1, col=2
)

fig_combined.update_xaxes(title_text='Years of Professional Experience', row=1, col=1)
fig_combined.update_xaxes(title_text='Years of Coding Experience', row=1, col=2)

fig_combined.update_yaxes(title_text='Density', row=1, col=1)
fig_combined.update_yaxes(title_text='Density', row=1, col=2)

fig_combined.update_layout(
    title_text='Distribution of Work and Coding Experience by Remote Work Status',
    height=500,
    width=1200,
    template='plotly_white',
    hovermode='closest'
)

fig_combined.show()
# Out:
# Years of Experience and Remote Work
#
# Work Experience:
# Remote Workers - Mean: 14.13, Median: 12.00
# Non-Remote Workers - Mean: 13.14, Median: 10.00
#
# Total Coding Experience:
# Remote Workers - Mean: 18.05, Median: 15.00
# Non-Remote Workers - Mean: 16.84, Median: 14.00
#
# Mann-Whitney U Tests:
# Work Experience:
# U-stat = 201977505.0000
# p-value = 2.8215e-57
# Significant: Yes
#
# Total Coding Experience:
# U-stat = 200976290.0000
# p-value = 3.8383e-51
# Significant: Yes

# %% [markdown]
# ### **Software Tool Use Counts for Work and Personal Projects Distribution**
#
# #### **Statistically Significant**
# The Mann–Whitney U tests show statistically significant differences between remote and non-remote workers for toolse use counts for both work and personal projects. (p < 0.05 for both). This indicates that the number of tools used is strongly associated with remote work status, even when extreme values are excluded.
#
# #### **Data Interpretation**
# Remote workers report using more software tools on average than non-remote workers in both categories. For work tools, remote workers have a higher mean (4.30 vs. 2.96) and a much higher median (4 vs. 0), suggesting that remote work is closely tied to broader tool use. Although the differences are statistically very strong, part of this effect may reflect the nature of remote work itself, which typically requires more digital tools, rather than purely individual preference or skill differences. Suggesting that higher tool usage is a clear and practical characteristic of remote work arrangements.

# %%
tools_remote = pd.DataFrame({
    'WorkTools': work_tool_count,
    'PersonalTools': personal_tool_count,
    'WorkToolGroups': work_tool_groups,
    'PersonalToolGroups': personal_tool_groups,
    'RemoteWork': target
})

tools_remote_clean = tools_remote.dropna()

# Using IQR to remove outliers for tool counts because there are joke answers but a specific reasonable number can't necessarily be set
q1_work = tools_remote_clean['WorkTools'].quantile(0.25)
q3_work = tools_remote_clean['WorkTools'].quantile(0.75)
iqr_work = q3_work - q1_work
lower_work = q1_work - 1.5 * iqr_work
upper_work = q3_work + 1.5 * iqr_work

q1_personal = tools_remote_clean['PersonalTools'].quantile(0.25)
q3_personal = tools_remote_clean['PersonalTools'].quantile(0.75)
iqr_personal = q3_personal - q1_personal
lower_personal = q1_personal - 1.5 * iqr_personal
upper_personal = q3_personal + 1.5 * iqr_personal

tools_remote_iqr = tools_remote_clean[
    (tools_remote_clean['WorkTools'] >= lower_work) & (tools_remote_clean['WorkTools'] <= upper_work) &
    (tools_remote_clean['PersonalTools'] >= lower_personal) & (tools_remote_clean['PersonalTools'] <= upper_personal)
]

remote_workers = tools_remote_iqr[tools_remote_iqr['RemoteWork'] == 1]
non_remote_workers = tools_remote_iqr[tools_remote_iqr['RemoteWork'] == 0]

print("Tool Usage and Remote Work (Outliers Removed via IQR)")
print("\nWork Tools:")
print(f"Remote Workers - Mean: {remote_workers['WorkTools'].mean():.2f}, Median: {remote_workers['WorkTools'].median():.2f}")
print(f"Non-Remote Workers - Mean: {non_remote_workers['WorkTools'].mean():.2f}, Median: {non_remote_workers['WorkTools'].median():.2f}")

print("\nPersonal Tools:")
print(f"Remote Workers - Mean: {remote_workers['PersonalTools'].mean():.2f}, Median: {remote_workers['PersonalTools'].median():.2f}")
print(f"Non-Remote Workers - Mean: {non_remote_workers['PersonalTools'].mean():.2f}, Median: {non_remote_workers['PersonalTools'].median():.2f}")

# We will do Mann-Whitney U tests since it is probably not normally distributed
stat_work, p_work = mannwhitneyu(remote_workers['WorkTools'], non_remote_workers['WorkTools'], alternative='two-sided')
stat_personal, p_personal = mannwhitneyu(remote_workers['PersonalTools'], non_remote_workers['PersonalTools'], alternative='two-sided')

print("\nMann-Whitney U Test (Work Tools):")
print(f"U-statistic = {stat_work:.4f}")
print(f"p-value = {p_work:.4e}")
print(f"Significant: {'Yes' if p_work < 0.05 else 'No'}")

print("\nMann-Whitney U Test (Personal Tools):")
print(f"U-statistic = {stat_personal:.4f}")
print(f"p-value = {p_personal:.4e}")
print(f"Significant: {'Yes' if p_personal < 0.05 else 'No'}")

work_groups_stats = tools_remote_iqr.groupby('WorkToolGroups').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
work_groups_stats.columns = ['ToolGroup', 'Remote_Count', 'Total_Count', 'Remote_Rate']

personal_groups_stats = tools_remote_iqr.groupby('PersonalToolGroups').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
personal_groups_stats.columns = ['ToolGroup', 'Remote_Count', 'Total_Count', 'Remote_Rate']

remote_color = funcs.get_color('Remote/Flexible')
non_remote_color = funcs.get_color('Non-Remote/Inflexible')

fig = go.Figure()
fig.add_trace(go.Box(y=remote_workers['WorkTools'], name='Remote/Flexible', marker_color=remote_color))
fig.add_trace(go.Box(y=non_remote_workers['WorkTools'], name='Non-Remote/Inflexible', marker_color=non_remote_color))
fig.update_layout(
    title='Number of Work Tools by Work Arrangement',
    yaxis_title='Number of Tools Used for Work',
    template='plotly_white',
    height=500
)
fig.show()

group_order = ['0', '1 to 5', '6 to 10', '11 to 15', '16 to 20', 'More than 20']
work_groups_stats['ToolGroup'] = pd.Categorical(work_groups_stats['ToolGroup'], categories=group_order, ordered=True)
work_groups_stats = work_groups_stats.sort_values('ToolGroup')

tool_group_colors = {grp: funcs.get_color(grp) for grp in work_groups_stats['ToolGroup'].unique()}

fig2 = px.bar(work_groups_stats, x='ToolGroup', y='Remote_Rate',
             title='Remote Work Rate by Number of Work Tools',
             labels={'Remote_Rate': 'Remote Work Rate', 'ToolGroup': 'Number of Work Tools'},
             text=work_groups_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='ToolGroup',
             color_discrete_map=tool_group_colors)
fig2.update_traces(textposition='outside')
fig2.update_layout(template='plotly_white', height=500, xaxis_tickangle=-30, showlegend=False)
fig2.show()

# Tool groups bar chart (Personal)
personal_groups_stats['ToolGroup'] = pd.Categorical(personal_groups_stats['ToolGroup'], categories=group_order, ordered=True)
personal_groups_stats = personal_groups_stats.sort_values('ToolGroup')

personal_group_color_map = {grp: funcs.get_color(grp) for grp in personal_groups_stats['ToolGroup'].unique()}

fig3 = px.bar(personal_groups_stats, x='ToolGroup', y='Remote_Rate',
             title='Remote Work Rate by Number of Personal Tools',
             labels={'Remote_Rate': 'Remote Work Rate', 'ToolGroup': 'Number of Personal Tools'},
             text=personal_groups_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='ToolGroup',
             color_discrete_map=personal_group_color_map)
fig3.update_traces(textposition='outside')
fig3.update_layout(template='plotly_white', height=500, xaxis_tickangle=-30, showlegend=False)
fig3.show()
# Out:
# Tool Usage and Remote Work (Outliers Removed via IQR)
#
# Work Tools:
# Remote Workers - Mean: 4.30, Median: 4.00
# Non-Remote Workers - Mean: 2.96, Median: 0.00
#
# Personal Tools:
# Remote Workers - Mean: 2.57, Median: 2.00
# Non-Remote Workers - Mean: 2.00, Median: 0.00
#
# Mann-Whitney U Test (Work Tools):
# U-statistic = 261260141.5000
# p-value = 9.6500e-266
# Significant: Yes
#
# Mann-Whitney U Test (Personal Tools):
# U-statistic = 245586165.5000
# p-value = 1.7103e-111
# Significant: Yes

# %% [markdown]
# ### **Programming Language Distribution**
#
# #### **Data Interpretation**
# The analysis of programming languages shows variation in remote work rates unrelated to the total users. Languages such as Elixir and Ruby exhibit the highest remote work participation, almost 50%, followed by Erlang, Go, Swift, and TypeScript, all above 40%. While widely used languages such as JavaScript, SQL, HTML/CSS, and Python are closer to the overall average, with remote work rates around the mid-to-high 30% range. While several language-specific associations are statistically significant, the total differences between most languages are relatively close. The older programming languages such as Prolog, Fortran, and Assembly may relate with legacy infrastructure, requiring on-site presence.

# %%
lang_with_target = pd.concat([language_features, target], axis=1)

lang_stats = []
for col in language_features.columns:
    users = lang_with_target[lang_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    lang_name = col.replace('lang_', '').replace('_', ' ').title()
    lang_stats.append({
        'Language': lang_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

lang_stats_df = pd.DataFrame(lang_stats).sort_values('Remote_Rate', ascending=False)

print("Programming Languages and Remote Work Rates")
print(lang_stats_df.to_string(index=False))

print("\nChi-Square Tests for Individual Languages:")

for idx, row in lang_stats_df.head(10).iterrows():
    col_name = [c for c in language_features.columns if c.replace('lang_', '').replace('_', ' ').title() == row['Language']][0]
    contingency = pd.crosstab(lang_with_target[col_name], lang_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Language']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

lang_colors = {lang: funcs.get_color(lang) for lang in lang_stats_df['Language']}

fig = px.bar(lang_stats_df, x='Language', y='Remote_Rate',
             title='Remote Work Rate by Programming Language',
             labels={'Remote_Rate': 'Remote Work Rate', 'Language': 'Programming Language'},
             text=lang_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='Language',
             color_discrete_map=lang_colors)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig.show()

fig2 = px.bar(lang_stats_df, x='Language', y='Total_Users',
             title='Number of Users by Programming Language',
             labels={'Total_Users': 'Number of Users', 'Language': 'Programming Language'},
             text=lang_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
             color='Language',
             color_discrete_map=lang_colors)
fig2.update_traces(textposition='outside')
fig2.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig2.show()
# Out:
# Programming Languages and Remote Work Rates
#              Language  Total_Users  Remote_Count  Remote_Rate
#                Elixir          847           415     0.489965
#                  Ruby         2046           994     0.485826
#                Erlang          465           204     0.438710
#                    Go         5219          2227     0.426710
#                 Swift         1719           698     0.406050
#            Typescript        13859          5617     0.405296
#                 Scala          843           340     0.403321
#                 Gleam          354           137     0.387006
#                   Sql        18633          7090     0.380508
#            Javascript        21005          7948     0.378386
# Bash Shell All Shells        15503          5755     0.371218
#                Groovy         1535           569     0.370684
#              Html Css        19698          7233     0.367195
# ...

# %% [markdown]
# ### **AI Model Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for AI model usage features (to be generated after running the analysis cell below).

# %%
ai_with_target = pd.concat([aimodel_features, target], axis=1)

ai_stats = []
for col in aimodel_features.columns:
    users = ai_with_target[ai_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('aimodel_', '').replace('_', ' ').title()
    ai_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

ai_stats_df = pd.DataFrame(ai_stats).sort_values('Remote_Rate', ascending=False)

print("AI Model Features and Remote Work Rates")
print(ai_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top AI Model Features:")
for idx, row in ai_stats_df.head(10).iterrows():
    col_name = [c for c in aimodel_features.columns if c.replace('aimodel_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(ai_with_target[col_name], ai_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

ai_colors = {s: funcs.get_color(s) for s in ai_stats_df['Skill']}

fig_ai = px.bar(ai_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by AI Model Feature',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'AI Model Feature'},
                text=ai_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=ai_colors)
fig_ai.update_traces(textposition='outside')
fig_ai.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_ai.show()

fig_ai_counts = px.bar(ai_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by AI Model Feature',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'AI Model Feature'},
                       text=ai_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=ai_colors)
fig_ai_counts.update_traces(textposition='outside')
fig_ai_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_ai_counts.show()
# Out:
# AI Model Features and Remote Work Rates
#                               Skill  Total_Users  Remote_Count  Remote_Rate
#            Anthropic: Claude Sonnet         7063          2981     0.422059
#         Gemini Pro Reasoning Models         4221          1672     0.396115
#      Openai Image Generating Models         4395          1724     0.392264
#             Openai Reasoning Models         5716          2238     0.391533
#           Openai Gpt Chatbot Models        13424          5211     0.388185
#               Meta Llama All Models         2941          1121     0.381163
# Gemini Flash General Purpose Models         5823          2177     0.373862
#              Microsoft Phi 4 Models          833           303     0.363745
#                 Amazon Titan Models          283           100     0.353357
#             Perplexity Sonar Models         1250           441     0.352800
#                       X Grok Models         1839           646     0.351278
# ...

# %% [markdown]
# ### **Collaboration Tools Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for collaboration tools (to be generated after running the analysis cell below).

# %%
collab_with_target = pd.concat([collab_features, target], axis=1)

collab_stats = []
for col in collab_features.columns:
    users = collab_with_target[collab_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('collab_', '').replace('_', ' ').title()
    collab_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

collab_stats_df = pd.DataFrame(collab_stats).sort_values('Remote_Rate', ascending=False)

print("Collaboration Tools and Remote Work Rates")
print(collab_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top Collaboration Tools:")
for idx, row in collab_stats_df.head(10).iterrows():
    col_name = [c for c in collab_features.columns if c.replace('collab_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(collab_with_target[col_name], collab_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

collab_colors = {s: funcs.get_color(s) for s in collab_stats_df['Skill']}

fig_collab = px.bar(collab_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by Collaboration Tool',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'Collaboration Tool'},
                text=collab_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=collab_colors)
fig_collab.update_traces(textposition='outside')
fig_collab.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_collab.show()

fig_collab_counts = px.bar(collab_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by Collaboration Tool',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'Collaboration Tool'},
                       text=collab_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=collab_colors)
fig_collab_counts.update_traces(textposition='outside')
fig_collab_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_collab_counts.show()
# Out:
# Collaboration Tools and Remote Work Rates
#                     Skill  Total_Users  Remote_Count  Remote_Rate
#                    Linear         1109           592     0.533814
# Lucid Includes Lucidchart         1580           760     0.481013
#                      Miro         4301          2001     0.465241
#                  Airtable          750           332     0.442667
#                    Notion         4964          2193     0.441781
#                Confluence         9864          4318     0.437753
#          Google Workspace         4566          1990     0.435830
#                      Jira        13976          6090     0.435747
#                      Coda          307           131     0.426710
#                     Asana         1313           555     0.422696
#                   Clickup         1178           483     0.410017
#              Azure Devops         5003          2043     0.408355
#                    Trello         4131          1632     0.395062
# ...

# %% [markdown]
# ### **Development Environment Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for development environment technologies (to be generated after running the analysis cell below).

# %%
devenv_with_target = pd.concat([devenv_features, target], axis=1)

devenv_stats = []
for col in devenv_features.columns:
    users = devenv_with_target[devenv_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('devenv_', '').replace('_', ' ').title()
    devenv_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

devenv_stats_df = pd.DataFrame(devenv_stats).sort_values('Remote_Rate', ascending=False)

print("Development Environments and Remote Work Rates")
print(devenv_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top DevEnv Features:")
for idx, row in devenv_stats_df.head(10).iterrows():
    col_name = [c for c in devenv_features.columns if c.replace('devenv_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(devenv_with_target[col_name], devenv_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

devenv_colors = {s: funcs.get_color(s) for s in devenv_stats_df['Skill']}

fig_devenv = px.bar(devenv_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by Development Environment',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'Development Environment'},
                text=devenv_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=devenv_colors)
fig_devenv.update_traces(textposition='outside')
fig_devenv.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_devenv.show()

fig_devenv_counts = px.bar(devenv_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by Development Environment',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'Development Environment'},
                       text=devenv_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=devenv_colors)
fig_devenv_counts.update_traces(textposition='outside')
fig_devenv_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_devenv_counts.show()
# Out:
# Development Environments and Remote Work Rates
#                       Skill  Total_Users  Remote_Count  Remote_Rate
#                      Cursor         4681          2107     0.450117
#                       Aider          504           223     0.442460
#                    Windsurf         1275           554     0.434510
#                 Claude Code         2538          1092     0.430260
#            Cline And Or Roo          574           246     0.428571
#                       Xcode         2622          1078     0.411137
#                         Zed         1906           775     0.406611
#                    Webstorm         2004           805     0.401697
#                       Rider         1869           739     0.395399
#                        Bolt          600           233     0.388333
#                    Phpstorm         1528           593     0.388089
#                 Lovable Dev          623           239     0.383628
# ...

# %% [markdown]
# ### **Web Framework Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for web framework technologies (to be generated after running the analysis cell below).

# %%
###
web_with_target = pd.concat([webframe_features, target], axis=1)

web_stats = []
for col in webframe_features.columns:
    users = web_with_target[web_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('webframe_', '').replace('_', ' ').title()
    web_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

web_stats_df = pd.DataFrame(web_stats).sort_values('Remote_Rate', ascending=False)

print("Web Framework Features and Remote Work Rates")
print(web_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top Web Frameworks:")
for idx, row in web_stats_df.head(10).iterrows():
    col_name = [c for c in webframe_features.columns if c.replace('webframe_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(web_with_target[col_name], web_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

web_colors = {s: funcs.get_color(s) for s in web_stats_df['Skill']}

fig_web = px.bar(web_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by Web Framework',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'Web Framework'},
                text=web_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=web_colors)
fig_web.update_traces(textposition='outside')
fig_web.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_web.show()

fig_web_counts = px.bar(web_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by Web Framework',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'Web Framework'},
                       text=web_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=web_colors)
fig_web_counts.update_traces(textposition='outside')
fig_web_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_web_counts.show()
# Out:
# Web Framework Features and Remote Work Rates
#         Skill  Total_Users  Remote_Count  Remote_Rate
#       Phoenix          568           292     0.514085
# Ruby On Rails         1395           706     0.506093
#        Nestjs         1596           716     0.448622
#       Fastify          692           300     0.433526
#         React        10596          4356     0.411099
#       Next Js         4933          2027     0.410906
#       Fastapi         3504          1393     0.397546
#         Astro         1058           420     0.396975
#        Drupal          526           205     0.389734
#       Node Js        11544          4467     0.386954
#       Symfony          949           366     0.385669
#  Asp Net Core         4664          1785     0.382719
#        Svelte         1717           657     0.382644
#       Express         4710          1801     0.382378
#        Jquery         5541          2093     0.377730
#       Asp Net         3360          1265     0.376488
# ...

# %% [markdown]
# ### **Hosting Platform Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for platform technologies (to be generated after running the analysis cell below).

# %%
plat_with_target = pd.concat([platform_features, target], axis=1)

plat_stats = []
for col in platform_features.columns:
    users = plat_with_target[plat_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('platform_', '').replace('_', ' ').title()
    plat_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

plat_stats_df = pd.DataFrame(plat_stats).sort_values('Remote_Rate', ascending=False)

print("Platform Features and Remote Work Rates")
print(plat_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top Platform Features:")
for idx, row in plat_stats_df.head(10).iterrows():
    col_name = [c for c in platform_features.columns if c.replace('platform_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(plat_with_target[col_name], plat_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

plat_colors = {s: funcs.get_color(s) for s in plat_stats_df['Skill']}

fig_plat = px.bar(plat_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by Platform Feature',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'Platform Feature'},
                text=plat_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=plat_colors)
fig_plat.update_traces(textposition='outside')
fig_plat.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_plat.show()

fig_plat_counts = px.bar(plat_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by Platform Feature',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'Platform Feature'},
                       text=plat_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=plat_colors)
fig_plat_counts.update_traces(textposition='outside')
fig_plat_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_plat_counts.show()
# Out:
# Platform Features and Remote Work Rates
#                   Skill  Total_Users  Remote_Count  Remote_Rate
#                 Datadog         2169          1245     0.573997
#               New Relic          936           488     0.521368
#               Terraform         4349          2147     0.493677
#                Homebrew         6291          2929     0.465586
# Amazon Web Services Aws        10618          4877     0.459314
#                    Yarn         5178          2324     0.448822
#                 Webpack         4500          2008     0.446222
#              Kubernetes         6993          3106     0.444158
#                  Heroku         1318           584     0.443096
#              Prometheus         2883          1265     0.438779
#           Digital Ocean         2621          1145     0.436856
#              Cloudflare         4923          2117     0.430022
#                Supabase         1320           561     0.425000
# ...

# %% [markdown]
# ### **Database Features Distribution**
#
# #### **Data Interpretation**
# A concise summary of key patterns for database-related technologies (to be generated after running the analysis cell below).

# %%
db_with_target = pd.concat([database_features, target], axis=1)

db_stats = []
for col in database_features.columns:
    users = db_with_target[db_with_target[col] == 1]
    remote_rate = users['RemoteWork'].mean()
    total_users = len(users)
    remote_count = users['RemoteWork'].sum()
    skill_name = col.replace('db_', '').replace('database_', '').replace('_', ' ').title()
    db_stats.append({
        'Skill': skill_name,
        'Total_Users': total_users,
        'Remote_Count': remote_count,
        'Remote_Rate': remote_rate
    })

db_stats_df = pd.DataFrame(db_stats).sort_values('Remote_Rate', ascending=False)

print("Database Features and Remote Work Rates")
print(db_stats_df.to_string(index=False))

print("\nChi-Square Tests for Top Database Features:")
for idx, row in db_stats_df.head(10).iterrows():
    col_name = [c for c in database_features.columns if c.replace('db_', '').replace('database_', '').replace('_', ' ').title() == row['Skill']][0]
    contingency = pd.crosstab(db_with_target[col_name], db_with_target['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{row['Skill']}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")

# Colors
db_colors = {s: funcs.get_color(s) for s in db_stats_df['Skill']}

fig_db = px.bar(db_stats_df, x='Skill', y='Remote_Rate',
                title='Remote Work Rate by Database Feature',
                labels={'Remote_Rate': 'Remote Work Rate', 'Skill': 'Database Feature'},
                text=db_stats_df['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
                color='Skill',
                color_discrete_map=db_colors)
fig_db.update_traces(textposition='outside')
fig_db.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_db.show()

fig_db_counts = px.bar(db_stats_df, x='Skill', y='Total_Users',
                       title='Number of Users by Database Feature',
                       labels={'Total_Users': 'Number of Users', 'Skill': 'Database Feature'},
                       text=db_stats_df['Total_Users'].apply(lambda x: f'{x:,}'),
                       color='Skill',
                       color_discrete_map=db_colors)
fig_db_counts.update_traces(textposition='outside')
fig_db_counts.update_layout(template='plotly_white', height=600, xaxis_tickangle=-45, showlegend=False)
fig_db_counts.show()
# Out:
# Database Features and Remote Work Rates
#                      Skill  Total_Users  Remote_Count  Remote_Rate
#                  Snowflake         1079           546     0.506024
#                   Dynamodb         2551          1234     0.483732
#                      Redis         7316          3341     0.456670
#                   Bigquery         1705           771     0.452199
#                 Clickhouse          627           281     0.448166
#            Amazon Redshift          611           272     0.445172
#                  Cosmos Db         1190           527     0.442857
#                     Valkey          632           277     0.438291
#             Databricks Sql          895           392     0.437989
#              Elasticsearch         4347          1886     0.433862
#                   Supabase         1558           649     0.416560
#                 Postgresql        14529          5977     0.411384
# ...

# %% [markdown]
# ### **AI Tool Usage Frequency**
#
# #### **Data Interpretation**
# A concise summary of key patterns for database-related technologies (to be generated after running the analysis cell below).

# %%
ai_freq_remote = pd.DataFrame({
    'AIFrequency': compressed_aiselect,
    'RemoteWork': target
})

# Filter out 'others' category
ai_freq_remote = ai_freq_remote[ai_freq_remote['AIFrequency'] != 'others']

ai_freq_stats = ai_freq_remote.groupby('AIFrequency').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
ai_freq_stats.columns = ['AIFrequency', 'Remote_Count', 'Total_Count', 'Remote_Rate']
ai_freq_stats = ai_freq_stats.sort_values('Remote_Rate', ascending=False)

print("AI Tool Usage Frequency and Remote Work Rates")
print(ai_freq_stats.to_string(index=False))

contingency_table = pd.crosstab(ai_freq_remote['AIFrequency'], ai_freq_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

ai_freq_color_map = {freq: funcs.get_color(freq) for freq in ai_freq_stats['AIFrequency']}

fig = px.bar(ai_freq_stats, x='AIFrequency', y='Remote_Rate',
             title='Remote Work Rate by AI Tool Usage Frequency',
             labels={'Remote_Rate': 'Remote Work Rate', 'AIFrequency': 'AI Usage Frequency'},
             text=ai_freq_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='AIFrequency',
             color_discrete_map=ai_freq_color_map)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig.show()
# Out:
# AI Tool Usage Frequency and Remote Work Rates
#  AIFrequency  Remote_Count  Total_Count  Remote_Rate
#        daily          6121        15883     0.385381
#       weekly          2088         5958     0.350453
# infrequently          1609         4628     0.347666
#           no          2314         7251     0.319128
#
# Chi-Square Test:
#   X² = 102.4121
#   p-value = 4.7075e-22
#   Significant: Yes

# %%
ai_agents_remote = pd.DataFrame({
    'AIAgents': compressed_aiagents,
    'RemoteWork': target
})

# Filter out 'others' category
ai_agents_remote = ai_agents_remote[ai_agents_remote['AIAgents'] != 'others']

ai_agents_stats = ai_agents_remote.groupby('AIAgents').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
ai_agents_stats.columns = ['AIAgents', 'Remote_Count', 'Total_Count', 'Remote_Rate']
ai_agents_stats = ai_agents_stats.sort_values('Remote_Rate', ascending=False)

print("AI Agents and Remote Work Rates")
print(ai_agents_stats.to_string(index=False))

contingency_table = pd.crosstab(ai_agents_remote['AIAgents'], ai_agents_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

ai_agents_color_map = {agent: funcs.get_color(agent) for agent in ai_agents_stats['AIAgents']}

fig = px.bar(ai_agents_stats, x='AIAgents', y='Remote_Rate',
             title='Remote Work Rate by AI Agents Usage',
             labels={'Remote_Rate': 'Remote Work Rate', 'AIAgents': 'AI Agents Usage'},
             text=ai_agents_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='AIAgents',
             color_discrete_map=ai_agents_color_map)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500, xaxis_tickangle=-45)
fig.show()
# Out:
# AI Agents and Remote Work Rates
# AIAgents  Remote_Count  Total_Count  Remote_Rate
#    daily          1792         4509     0.397427
#   weekly          1112         2868     0.387727
#  monthly           912         2498     0.365092
#       no          7723        22044     0.350345
#
# Chi-Square Test:
#   X² = 45.7854
#   p-value = 6.2998e-10
#   Significant: Yes

# %% [markdown]
# ### **Learning AI in the Past Year Frequency**
#
# #### **Data Interpretation**
# A concise summary of key patterns for database-related technologies (to be generated after running the analysis cell below).

# %%
learn_ai_remote = pd.DataFrame({
    'LearnAI': compressed_learncodeai,
    'RemoteWork': target
})

# Filter out 'others' category
learn_ai_remote = learn_ai_remote[learn_ai_remote['LearnAI'] != 'others']

learn_ai_stats = learn_ai_remote.groupby('LearnAI').agg({
    'RemoteWork': ['sum', 'count', 'mean']
}).reset_index()
learn_ai_stats.columns = ['LearnAI', 'Remote_Count', 'Total_Count', 'Remote_Rate']
learn_ai_stats = learn_ai_stats.sort_values('Remote_Rate', ascending=False)

print("Learning AI Tools in Past Year and Remote Work Rates")
print(learn_ai_stats.to_string(index=False))

contingency_table = pd.crosstab(learn_ai_remote['LearnAI'], learn_ai_remote['RemoteWork'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-Square Test:")
print(f"  X² = {chi2:.4f}")
print(f"  p-value = {p_value:.4e}")
print(f"  Significant: {'Yes' if p_value < 0.05 else 'No'}")

learn_ai_color_map = {learn: funcs.get_color(learn) for learn in learn_ai_stats['LearnAI']}

fig = px.bar(learn_ai_stats, x='LearnAI', y='Remote_Rate',
             title='Remote Work Rate by AI Learning Status',
             labels={'Remote_Rate': 'Remote Work Rate', 'LearnAI': 'Learned AI Tools in Past Year'},
             text=learn_ai_stats['Remote_Rate'].apply(lambda x: f'{x*100:.1f}%'),
             color='LearnAI',
             color_discrete_map=learn_ai_color_map)
fig.update_traces(textposition='outside')
fig.update_layout(template='plotly_white', height=500)
fig.show()
# Out:
# Learning AI Tools in Past Year and Remote Work Rates
# LearnAI  Remote_Count  Total_Count  Remote_Rate
#     yes         10748        30430     0.353204
#      no          4384        14771     0.296798
#
# Chi-Square Test:
#   X² = 141.8160
#   p-value = 1.0669e-32
#   Significant: Yes

# %% [markdown]
# ### **Correlation Analysis**
#
# #### **Data Interpretation**
# A concise summary of key patterns for database-related technologies (to be generated after running the analysis cell below).

# %%
# Correlation Analysis All Data
all_features = pd.concat([
    current_profession_encoded,
    age_group,
    education_level,
    employment_status,
    dev_type_encoded,
    geographic_regions_encoded,
    pd.DataFrame({'org_size': org_size_ordinal}),
    pd.DataFrame({'work_exp': work_years}),
    pd.DataFrame({'years_code': learn_years}),
    pd.DataFrame({'work_tools': work_tool_count}),
    pd.DataFrame({'personal_tools': personal_tool_count}),
    language_features,
    database_features,
    platform_features,
    webframe_features,
    devenv_features,
    collab_features,
    aimodel_features,
    learncodeai_encoded,
    aiselect_encoded,
    aiagents_encoded,
    aiagentchange_encoded,
    target.rename('RemoteWork')
], axis=1)

print(f"Total features: {all_features.shape[1] - 1}")
print(f"Total samples: {all_features.shape[0]}")
print(f"Missing values: {all_features.isnull().sum().sum()}")

correlations_with_target = all_features.corr()['RemoteWork'].drop('RemoteWork').sort_values(ascending=False)

top_positive = correlations_with_target.head(30)
top_negative = correlations_with_target.tail(30)
top_correlations = pd.concat([top_positive, top_negative])

fig = px.bar(x=top_correlations.values, y=top_correlations.index, orientation='h',
             title='Top Features Correlated with Remote Work',
             labels={'x': 'Correlation Coefficient', 'y': 'Feature'},
             color=top_correlations.values,
             color_continuous_scale='RdBu_r',
             color_continuous_midpoint=0)
fig.update_layout(template='plotly_white', height=800)
fig.show()
# Out:
# Total features: 301
# Total samples: 49191
# Missing values: 12447

# %% [markdown]
# Upon the first look at the graph, we can see a lot of 'others' categories. These categories mostly include imputed missing values, so it would make more sense to remove them for better results.

# %%
#Remove others categorys which are not meaningful and can skew correlation analysis, and drop rows with missing values for a cleaner correlation matrix.
learncodeai_encoded = learncodeai_encoded.drop(columns=['learncodeai_others'])
aiselect_encoded = aiselect_encoded.drop(columns=['aiselect_others'])
aiagents_encoded = aiagents_encoded.drop(columns=['aiagents_others'])
aiagentchange_encoded = aiagentchange_encoded.drop(columns=['aiagentchange_others'])
employment_status = employment_status.drop(columns=['employment_others'])
age_group = age_group.drop(columns=['age_group_Prefer not to say'])
geographic_regions_encoded = geographic_regions_encoded.drop(columns=['region_other'])
dev_type_encoded = dev_type_encoded.drop(columns=['devtype_others'])

# Correlation Analysis All Data
all_features = all_features.dropna()
all_features = all_features.drop(columns=['learncodeai_others', 'aiselect_others', 'aiagents_others', 'aiagentchange_others', 'employment_others', 'age_group_Prefer not to say', 'region_other', 'devtype_others'])  # Remove 'other' categories

print(f"Total features: {all_features.shape[1] - 1}")
print(f"Total samples: {all_features.shape[0]}")
print(f"Missing values: {all_features.isnull().sum().sum()}")

correlations_with_target = all_features.corr()['RemoteWork'].drop('RemoteWork').sort_values(ascending=False)

top_positive = correlations_with_target.head(30)
top_negative = correlations_with_target.tail(30)
top_correlations = pd.concat([top_positive, top_negative])

fig = px.bar(x=top_correlations.values, y=top_correlations.index, orientation='h',
             title='Top Features Correlated with Remote Work',
             labels={'x': 'Correlation Coefficient', 'y': 'Feature'},
             color=top_correlations.values,
             color_continuous_scale='RdBu_r',
             color_continuous_midpoint=0)
fig.update_layout(template='plotly_white', height=800)
fig.show()
# Out:
# Total features: 293
# Total samples: 39869
# Missing values: 0

# %% [markdown]
# It is quite interesting to see that being employed has a negative correlation with remote work. This may be caused by several freelancers populating the dataset.
#
# Since we removed some columns, let us check if the present features pass the chi-square test again.

# %%
#chi2 test for features with other categories removed
print("\nChi-Square Tests for Top Features (Other Categories Removed):")
for feature in top_correlations.index:
    contingency = pd.crosstab(all_features[feature], all_features['RemoteWork'])
    if contingency.shape == (2, 2):
        chi2, p_val, _, _ = chi2_contingency(contingency)
        print(f"{feature}: X²={chi2:.2f}, p={p_val:.4e}, {'Yes' if p_val < 0.05 else 'No'}")
# Out:
# Chi-Square Tests for Top Features (Other Categories Removed):
# employment_employed: X²=1355.42, p=1.0241e-296, Yes
# platform_amazon_web_services_aws: X²=591.47, p=1.1981e-130, Yes
# profession_professional dev: X²=576.31, p=2.3830e-127, Yes
# collab_jira: X²=458.13, p=1.2276e-101, Yes
# platform_datadog: X²=435.41, p=1.0775e-96, Yes
# region_northern_america: X²=413.69, p=5.7790e-92, Yes
# platform_homebrew: X²=362.40, p=8.4480e-81, Yes
# platform_docker: X²=354.19, p=5.1748e-79, Yes
# platform_terraform: X²=349.89, p=4.4803e-78, Yes
# db_redis: X²=349.90, p=4.4541e-78, Yes
# collab_confluence: X²=285.62, p=4.4755e-64, Yes
# db_postgresql: X²=278.89, p=1.3101e-62, Yes
# lang_typescript: X²=248.43, p=5.7101e-56, Yes
# platform_kubernetes: X²=240.34, p=3.3126e-54, Yes
# webframe_react: X²=233.78, p=8.9386e-53, Yes
# platform_npm: X²=227.48, p=2.1125e-51, Yes
# collab_miro: X²=219.03, p=1.4720e-49, Yes
# collab_notion: X²=210.97, p=8.4518e-48, Yes
# ...

# %% [markdown]
# All features are still statistically significant! Let us start training some classification models.

# %%
# Store variables for use in other notebook
# %store target
# %store current_profession_encoded
# %store age_group
# %store education_level
# %store employment_status
# %store dev_type_encoded
# %store work_years
# %store learn_years
# %store org_size_ordinal
# %store work_tool_count
# %store personal_tool_count
# %store geographic_regions_encoded
# %store language_features
# %store database_features
# %store platform_features
# %store webframe_features
# %store devenv_features
# %store collab_features
# %store aimodel_features
# %store ai_industry_use
# %store ai_learn_how
# %store learncodeai_encoded
# %store aiselect_encoded
# %store aiagents_encoded
# %store aiagentchange_encoded
# %store ai_technical_use
# %store ai_knowledge
# %store ai_orchestration
# %store ai_observe_secure
# %store ai_external
# %store survey_data
# %store survey_schema
# %store funcs
# Out:
# Stored 'target' (Series)
# Stored 'current_profession_encoded' (DataFrame)
# Stored 'age_group' (DataFrame)
# Stored 'education_level' (DataFrame)
# Stored 'employment_status' (DataFrame)
# Stored 'dev_type_encoded' (DataFrame)
# Stored 'work_years' (Series)
# Stored 'learn_years' (Series)
# Stored 'org_size_ordinal' (Series)
# Stored 'work_tool_count' (Series)
# Stored 'personal_tool_count' (Series)
# Stored 'geographic_regions_encoded' (DataFrame)
# Stored 'language_features' (DataFrame)
# Stored 'database_features' (DataFrame)
# Stored 'platform_features' (DataFrame)
# Stored 'webframe_features' (DataFrame)
# Stored 'devenv_features' (DataFrame)
# Stored 'collab_features' (DataFrame)
# Stored 'aimodel_features' (DataFrame)
# Stored 'ai_industry_use' (DataFrame)
# Stored 'ai_learn_how' (DataFrame)
# Stored 'learncodeai_encoded' (DataFrame)
# Stored 'aiselect_encoded' (DataFrame)
# Stored 'aiagents_encoded' (DataFrame)
# Stored 'aiagentchange_encoded' (DataFrame)
# ...
